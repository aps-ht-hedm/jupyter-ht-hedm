# %% [markdown]
# # Bluesky-based control development for 2020-2 run
#
# Test the OOP-based experiment control for
# * Tomography
# * Near field
# * Far field

# %% [markdown]
# ## Preparation

# %%
import numpy as np
import matplotlib
import bluesky
import ophyd
import apstools
import databroker
from datetime import datetime

# %%
scan_cfg = 'seisidd/config/scan_template.yml'

# %% [markdown]
# ## Tomography

# %%
# instantiate the experiment handle
from seisidd.experiment import Tomography

testTomo = Tomography(mode='dryrun')

# %%
# summarize plan
testTomo.dryrun(scan_cfg)
# Out:
# att__motor -> 1
# foil__motor -> 1
# Tomo configuration:
# energyfoil = 1
# attenuation = EpicsMotorTuple(user_readback=1.008, user_setpoint=1.0, user_offset=0.0, user_offset_dir=0, offset_freeze_switch=0, set_use_switch=0, velocity=2.1, acceleration=1.0, motor_egu='pos', motor_is_moving=0, motor_done_move=1, high_limit_switch=0, low_limit_switch=0, high_limit_travel=24.5, low_limit_travel=0.5, direction_of_travel=1, motor_stop=0, home_forward=0, home_reverse=0)
# type = step
# n_white = 5
# n_dark = 5
# sample_out_position:
#   kx = -1
#   kz = 0
# acquire_time = 0.5
# acquire_period = 0.51
# omega_step = 0.5
# omega_start = 0.0
# omega_end = 20.0
# n_frames = 5
# ROT_STAGE_FAST_SPEED = 1
# accl = 3
# readout_time = 0.001
# n_projections = 41
# total_images = 56
# focus_beam = False
# initial_kx = -2.0
# initial_kz = 0.0
# fronte_white_kx = -3.0
# fronte_white_kz = 0.0
# back_white_kx = -2.9396926207859084
# back_white_kz = 0.3420201433256687
#
# Output:
# filepath = /home/beams/S6HEDM/data/ssd/test_pre2020-2
# fileprefix = test2020_2
# type = tiff
#
# =================================== Open Run ===================================
# det_tiff1_file_name -> test2020_2
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 56
# det_tiff1_file_template -> %s%s_%06d.tiff
# det_hdf1_file_name -> test2020_2
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 56
# det_hdf1_file_template -> %s%s_%06d.tiff
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_acquire_time -> 0.5
# det_cam1_acquire_period -> 0.51
# det_cam1_frame_type -> 0
# tomostage_kx -> -3.0
# tomostage_kz -> 0.0
# det_proc1_nd_array_port -> TRANS1
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_trans1_enable -> 1
# det_proc1_enable -> 1
# det_proc1_enable_filter -> 1
# det_proc1_filter_type -> Average
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 5
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 25
#   Read ['det']
# tomostage_kx -> -2.0
# tomostage_kz -> 0.0
# det_cam1_frame_type -> 1
# det_proc1_nd_array_port -> TRANS1
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_trans1_enable -> 1
# det_proc1_enable -> 1
# det_proc1_enable_filter -> 1
# det_proc1_filter_type -> Average
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 5
# det_cam1_num_images -> 5
# tomostage_rot -> 0.0
#   Read ['det']
# tomostage_rot -> 0.5
#   Read ['det']
# tomostage_rot -> 1.0
#   Read ['det']
# tomostage_rot -> 1.5
#   Read ['det']
# tomostage_rot -> 2.0
#   Read ['det']
# tomostage_rot -> 2.5
#   Read ['det']
# tomostage_rot -> 3.0
#   Read ['det']
# tomostage_rot -> 3.5
#   Read ['det']
# tomostage_rot -> 4.0
#   Read ['det']
# tomostage_rot -> 4.5
#   Read ['det']
# tomostage_rot -> 5.0
#   Read ['det']
# tomostage_rot -> 5.5
#   Read ['det']
# tomostage_rot -> 6.0
#   Read ['det']
# tomostage_rot -> 6.5
#   Read ['det']
# tomostage_rot -> 7.0
#   Read ['det']
# tomostage_rot -> 7.5
#   Read ['det']
# tomostage_rot -> 8.0
#   Read ['det']
# tomostage_rot -> 8.5
#   Read ['det']
# tomostage_rot -> 9.0
#   Read ['det']
# tomostage_rot -> 9.5
#   Read ['det']
# tomostage_rot -> 10.0
#   Read ['det']
# tomostage_rot -> 10.5
#   Read ['det']
# tomostage_rot -> 11.0
#   Read ['det']
# tomostage_rot -> 11.5
#   Read ['det']
# tomostage_rot -> 12.0
#   Read ['det']
# tomostage_rot -> 12.5
#   Read ['det']
# tomostage_rot -> 13.0
#   Read ['det']
# tomostage_rot -> 13.5
#   Read ['det']
# tomostage_rot -> 14.0
#   Read ['det']
# tomostage_rot -> 14.5
#   Read ['det']
# tomostage_rot -> 15.0
#   Read ['det']
# tomostage_rot -> 15.5
#   Read ['det']
# tomostage_rot -> 16.0
#   Read ['det']
# tomostage_rot -> 16.5
#   Read ['det']
# tomostage_rot -> 17.0
#   Read ['det']
# tomostage_rot -> 17.5
#   Read ['det']
# tomostage_rot -> 18.0
#   Read ['det']
# tomostage_rot -> 18.5
#   Read ['det']
# tomostage_rot -> 19.0
#   Read ['det']
# tomostage_rot -> 19.5
#   Read ['det']
# tomostage_rot -> 20.0
#   Read ['det']
# det_cam1_frame_type -> 2
# tomostage_kx -> -2.9396926207859084
# tomostage_kz -> 0.3420201433256687
# det_proc1_nd_array_port -> TRANS1
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_trans1_enable -> 1
# det_proc1_enable -> 1
# det_proc1_enable_filter -> 1
# det_proc1_filter_type -> Average
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 5
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 25
#   Read ['det']
# tomostage_kx -> -2.0
# tomostage_kz -> 0.0
# det_cam1_frame_type -> 3
# A_shutter -> close
# det_proc1_nd_array_port -> TRANS1
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_trans1_enable -> 1
# det_proc1_enable -> 1
# det_proc1_enable_filter -> 1
# det_proc1_filter_type -> Average
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 5
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 25
#   Read ['det']
# ================================== Close Run ===================================

# %%
testTomo.check(scan_cfg)
# Out:
# Tomo configuration:
# energyfoil = 1
# attenuation = 1
# type = step
# n_white = 5
# n_dark = 5
# sample_out_position:
#   kx = -1
#   kz = 0
# acquire_time = 0.5
# acquire_period = 0.51
# omega_step = 0.5
# omega_start = 0.0
# omega_end = 20.0
# n_frames = 5
# ROT_STAGE_FAST_SPEED = 1
# accl = 3
# readout_time = 0.001
#
# Output:
# filepath = /home/beams/S6HEDM/data/ssd/test_pre2020-2
# fileprefix = test2020_2
# type = tiff

# %%
testTomo.run(scan_cfg)
# Out:
# Tomo configuration:
# energyfoil = 1
# attenuation = EpicsMotorTuple(user_readback=1.008, user_setpoint=1.0, user_offset=0.0, user_offset_dir=0, offset_freeze_switch=0, set_use_switch=0, velocity=2.1, acceleration=1.0, motor_egu='pos', motor_is_moving=0, motor_done_move=1, high_limit_switch=0, low_limit_switch=0, high_limit_travel=24.5, low_limit_travel=0.5, direction_of_travel=1, motor_stop=0, home_forward=0, home_reverse=0)
# type = step
# n_white = 5
# n_dark = 5
# sample_out_position:
#   kx = -1
#   kz = 0
# acquire_time = 0.5
# acquire_period = 0.51
# omega_step = 0.5
# omega_start = 0.0
# omega_end = 20.0
# n_frames = 5
# ROT_STAGE_FAST_SPEED = 1
# accl = 3
# readout_time = 0.001
# n_projections = 41
# total_images = 56
# focus_beam = False
# initial_kx = -2.0
# initial_kz = 0.0
# fronte_white_kx = -3.0
# fronte_white_kz = 0.0
# back_white_kx = -2.9396926207859084
# back_white_kz = 0.3420201433256687
#
# Output:
# filepath = /home/beams/S6HEDM/data/ssd/test_pre2020-2
# fileprefix = test2020_2
# type = tiff
#
#
#
# Transient Scan ID: 1     Time: 2020-07-05 17:16:40
# Persistent Unique Scan ID: '139bbb91-6111-4ada-8405-1312cf59ff2c'
# New stream: 'primary'
# +-----------+------------+
# |   seq_num |       time |
# +-----------+------------+
# |         1 | 17:16:54.9 |
# |         2 | 17:17:04.0 |
# |         3 | 17:17:07.6 |
# |         4 | 17:17:11.1 |
# |         5 | 17:17:14.7 |
# |         6 | 17:17:18.3 |
# |         7 | 17:17:21.9 |
# |         8 | 17:17:25.4 |
# |         9 | 17:17:29.0 |
# |        10 | 17:17:32.6 |
# |        11 | 17:17:36.1 |
# |        12 | 17:17:39.7 |
# |        13 | 17:17:43.3 |
# |        14 | 17:17:46.8 |
# |        15 | 17:17:50.4 |
# |        16 | 17:17:54.0 |
# |        17 | 17:17:57.6 |
# |        18 | 17:18:01.1 |
# |        19 | 17:18:04.7 |
# |        20 | 17:18:08.3 |
# |        21 | 17:18:11.8 |
# |        22 | 17:18:15.4 |
# |        23 | 17:18:19.0 |
# |        24 | 17:18:22.5 |
# |        25 | 17:18:26.1 |
# |        26 | 17:18:29.7 |
# |        27 | 17:18:33.2 |
# |        28 | 17:18:36.8 |
# |        29 | 17:18:40.4 |
# |        30 | 17:18:44.0 |
# |        31 | 17:18:47.5 |
# |        32 | 17:18:51.1 |
# |        33 | 17:18:54.7 |
# |        34 | 17:18:58.2 |
# |        35 | 17:19:01.8 |
# |        36 | 17:19:05.4 |
# |        37 | 17:19:08.9 |
# |        38 | 17:19:12.5 |
# |        39 | 17:19:16.1 |
# |        40 | 17:19:19.6 |
# |        41 | 17:19:23.2 |
# |        42 | 17:19:26.8 |
# |        43 | 17:19:41.6 |
# |        44 | 17:19:56.4 |
# +-----------+------------+
# generator tomo_scan ['139bbb91'] (scan num: 1)
# ('139bbb91-6111-4ada-8405-1312cf59ff2c',)

# %% [markdown]
# ## Near-field

# %%
# instantiate the experiment handle
from seisidd.experiment import NearField

testNF = NearField(mode='dryrun')

# %%
testNF.dryrun(scan_cfg)
# Out:
# NearField configuration:
# energyfoil = 1
# attenuation = 1
# type = fly
# sample_out_position:
#   kx = -1
#   kz = 0
# detector_z_position:
#   nf_z1 = 7
#   nf_z2 = 10
# volume:
#   ky_start = 2.5
#   ky_step = 0.5
#   n_layers = 10
# acquire_time = 0.1
# omega_step = 0.2
# omega_start = 0.0
# omega_end = 360.0
# n_frames = 1
# ROT_STAGE_FAST_SPEED = 1
# accl = 3
# readout_time = 0.001
# n_projections = 1801
# total_images = 1801
# focus_beam = False
# slew_speed = 1.9790985206238558
# initial_kx = 0.0
# initial_kz = 0.0
# fronte_white_kx = -1.0
# fronte_white_kz = 0.0
# back_white_kx = -1.0
# back_white_kz = 0.0
#
# Output:
# filepath = /data
# fileprefix = test
# type = tif
#
# nfstage_ky -> 2.5
# =================================== Open Run ===================================
# det_tiff1_file_path -> /data
# det_tiff1_file_name -> test_layer000001
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 3602
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> /data
# det_hdf1_file_name -> test_layer000001
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 3602
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 1
# nfposition -> 7
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 360.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9790985206238558
# psofly_taxi -> Taxi
# det_cam1_num_images -> 1801
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# nfposition -> 10
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 360.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9790985206238558
# psofly_taxi -> Taxi
# det_cam1_num_images -> 1801
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# ================================== Close Run ===================================
# nfstage_ky -> 3.0
# =================================== Open Run ===================================
# det_tiff1_file_path -> /data
# det_tiff1_file_name -> test_layer000002
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 3602
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> /data
# det_hdf1_file_name -> test_layer000002
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 3602
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 1
# nfposition -> 7
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 360.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9790985206238558
# psofly_taxi -> Taxi
# det_cam1_num_images -> 1801
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# nfposition -> 10
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 360.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9790985206238558
# psofly_taxi -> Taxi
# det_cam1_num_images -> 1801
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# ================================== Close Run ===================================
# nfstage_ky -> 3.5
# =================================== Open Run ===================================
# det_tiff1_file_path -> /data
# det_tiff1_file_name -> test_layer000003
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 3602
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> /data
# det_hdf1_file_name -> test_layer000003
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 3602
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 1
# nfposition -> 7
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 360.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9790985206238558
# psofly_taxi -> Taxi
# det_cam1_num_images -> 1801
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# nfposition -> 10
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 360.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9790985206238558
# psofly_taxi -> Taxi
# det_cam1_num_images -> 1801
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# ================================== Close Run ===================================
# nfstage_ky -> 4.0
# =================================== Open Run ===================================
# det_tiff1_file_path -> /data
# det_tiff1_file_name -> test_layer000004
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 3602
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> /data
# det_hdf1_file_name -> test_layer000004
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 3602
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 1
# nfposition -> 7
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 360.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9790985206238558
# psofly_taxi -> Taxi
# det_cam1_num_images -> 1801
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# nfposition -> 10
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 360.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9790985206238558
# psofly_taxi -> Taxi
# det_cam1_num_images -> 1801
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# ================================== Close Run ===================================
# nfstage_ky -> 4.5
# =================================== Open Run ===================================
# det_tiff1_file_path -> /data
# det_tiff1_file_name -> test_layer000005
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 3602
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> /data
# det_hdf1_file_name -> test_layer000005
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 3602
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 1
# nfposition -> 7
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 360.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9790985206238558
# psofly_taxi -> Taxi
# det_cam1_num_images -> 1801
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# nfposition -> 10
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 360.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9790985206238558
# psofly_taxi -> Taxi
# det_cam1_num_images -> 1801
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# ================================== Close Run ===================================
# nfstage_ky -> 5.0
# =================================== Open Run ===================================
# det_tiff1_file_path -> /data
# det_tiff1_file_name -> test_layer000006
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 3602
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> /data
# det_hdf1_file_name -> test_layer000006
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 3602
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 1
# nfposition -> 7
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 360.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9790985206238558
# psofly_taxi -> Taxi
# det_cam1_num_images -> 1801
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# nfposition -> 10
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 360.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9790985206238558
# psofly_taxi -> Taxi
# det_cam1_num_images -> 1801
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# ================================== Close Run ===================================
# nfstage_ky -> 5.5
# =================================== Open Run ===================================
# det_tiff1_file_path -> /data
# det_tiff1_file_name -> test_layer000007
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 3602
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> /data
# det_hdf1_file_name -> test_layer000007
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 3602
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 1
# nfposition -> 7
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 360.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9790985206238558
# psofly_taxi -> Taxi
# det_cam1_num_images -> 1801
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# nfposition -> 10
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 360.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9790985206238558
# psofly_taxi -> Taxi
# det_cam1_num_images -> 1801
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# ================================== Close Run ===================================
# nfstage_ky -> 6.0
# =================================== Open Run ===================================
# det_tiff1_file_path -> /data
# det_tiff1_file_name -> test_layer000008
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 3602
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> /data
# det_hdf1_file_name -> test_layer000008
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 3602
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 1
# nfposition -> 7
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 360.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9790985206238558
# psofly_taxi -> Taxi
# det_cam1_num_images -> 1801
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# nfposition -> 10
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 360.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9790985206238558
# psofly_taxi -> Taxi
# det_cam1_num_images -> 1801
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# ================================== Close Run ===================================
# nfstage_ky -> 6.5
# =================================== Open Run ===================================
# det_tiff1_file_path -> /data
# det_tiff1_file_name -> test_layer000009
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 3602
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> /data
# det_hdf1_file_name -> test_layer000009
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 3602
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 1
# nfposition -> 7
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 360.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9790985206238558
# psofly_taxi -> Taxi
# det_cam1_num_images -> 1801
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# nfposition -> 10
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 360.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9790985206238558
# psofly_taxi -> Taxi
# det_cam1_num_images -> 1801
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# ================================== Close Run ===================================
# nfstage_ky -> 7.0
# =================================== Open Run ===================================
# det_tiff1_file_path -> /data
# det_tiff1_file_name -> test_layer000010
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 3602
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> /data
# det_hdf1_file_name -> test_layer000010
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 3602
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 1
# nfposition -> 7
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 360.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9790985206238558
# psofly_taxi -> Taxi
# det_cam1_num_images -> 1801
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# nfposition -> 10
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 360.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9790985206238558
# psofly_taxi -> Taxi
# det_cam1_num_images -> 1801
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# ================================== Close Run ===================================

# %% [markdown]
# ## Far-field

# %%
from seisidd.experiment import FarField

testFF = FarField(mode='dryrun')

# %%
testFF.dryrun(scan_cfg)
# Out:
# FarField configuration:
# energyfoil = 1
# attenuation = 1
# type = fly
# sample_out_position:
#   kx = -1
#   kz = 0
# detector_z_position:
#   ff_z1 = 7
# volume:
#   ky_start = 2.5
#   ky_step = 0.5
#   n_layers = 10
# n_dark = 5
# acquire_time = 0.1
# acquire_period = 0.11
# omega_step = 0.2
# omega_start = 0.0
# omega_end = 10.0
# n_frames = 1
# ROT_STAGE_FAST_SPEED = 1
# accl = 3
# readout_time = 0.001
# n_projections = 51
# total_images = 61
# focus_beam = False
# slew_speed = 1.9413706076489998
# initial_kx = 0.0
# initial_kz = 0.0
# fronte_white_kx = -1.0
# fronte_white_kz = 0.0
# back_white_kx = -0.984807753012208
# back_white_kz = 0.17364817766693033
#
# Output:
# filepath = /data
# fileprefix = test
# type = tif
#
# ffstage_ky -> 2.5
# =================================== Open Run ===================================
# det_tiff1_file_path -> /data
# det_tiff1_file_name -> test_layer000001
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 61
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> /data
# det_hdf1_file_name -> test_layer000001
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 61
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 3
# A_shutter -> close
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
#   Read ['det']
# ================================== Close Run ===================================
# det_cam1_frame_type -> 1
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 10.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9413706076489998
# psofly_taxi -> Taxi
# det_cam1_num_images -> 51
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# det_cam1_frame_type -> 3
# A_shutter -> close
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
#   Read ['det']
# ================================== Close Run ===================================
# ================================== Close Run ===================================
# ffstage_ky -> 3.0
# =================================== Open Run ===================================
# det_tiff1_file_path -> /data
# det_tiff1_file_name -> test_layer000002
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 61
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> /data
# det_hdf1_file_name -> test_layer000002
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 61
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 3
# A_shutter -> close
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
#   Read ['det']
# ================================== Close Run ===================================
# det_cam1_frame_type -> 1
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 10.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9413706076489998
# psofly_taxi -> Taxi
# det_cam1_num_images -> 51
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# det_cam1_frame_type -> 3
# A_shutter -> close
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
#   Read ['det']
# ================================== Close Run ===================================
# ================================== Close Run ===================================
# ffstage_ky -> 3.5
# =================================== Open Run ===================================
# det_tiff1_file_path -> /data
# det_tiff1_file_name -> test_layer000003
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 61
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> /data
# det_hdf1_file_name -> test_layer000003
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 61
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 3
# A_shutter -> close
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
#   Read ['det']
# ================================== Close Run ===================================
# det_cam1_frame_type -> 1
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 10.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9413706076489998
# psofly_taxi -> Taxi
# det_cam1_num_images -> 51
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# det_cam1_frame_type -> 3
# A_shutter -> close
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
#   Read ['det']
# ================================== Close Run ===================================
# ================================== Close Run ===================================
# ffstage_ky -> 4.0
# =================================== Open Run ===================================
# det_tiff1_file_path -> /data
# det_tiff1_file_name -> test_layer000004
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 61
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> /data
# det_hdf1_file_name -> test_layer000004
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 61
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 3
# A_shutter -> close
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
#   Read ['det']
# ================================== Close Run ===================================
# det_cam1_frame_type -> 1
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 10.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9413706076489998
# psofly_taxi -> Taxi
# det_cam1_num_images -> 51
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# det_cam1_frame_type -> 3
# A_shutter -> close
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
#   Read ['det']
# ================================== Close Run ===================================
# ================================== Close Run ===================================
# ffstage_ky -> 4.5
# =================================== Open Run ===================================
# det_tiff1_file_path -> /data
# det_tiff1_file_name -> test_layer000005
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 61
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> /data
# det_hdf1_file_name -> test_layer000005
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 61
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 3
# A_shutter -> close
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
#   Read ['det']
# ================================== Close Run ===================================
# det_cam1_frame_type -> 1
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 10.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9413706076489998
# psofly_taxi -> Taxi
# det_cam1_num_images -> 51
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# det_cam1_frame_type -> 3
# A_shutter -> close
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
#   Read ['det']
# ================================== Close Run ===================================
# ================================== Close Run ===================================
# ffstage_ky -> 5.0
# =================================== Open Run ===================================
# det_tiff1_file_path -> /data
# det_tiff1_file_name -> test_layer000006
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 61
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> /data
# det_hdf1_file_name -> test_layer000006
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 61
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 3
# A_shutter -> close
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
#   Read ['det']
# ================================== Close Run ===================================
# det_cam1_frame_type -> 1
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 10.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9413706076489998
# psofly_taxi -> Taxi
# det_cam1_num_images -> 51
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# det_cam1_frame_type -> 3
# A_shutter -> close
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
#   Read ['det']
# ================================== Close Run ===================================
# ================================== Close Run ===================================
# ffstage_ky -> 5.5
# =================================== Open Run ===================================
# det_tiff1_file_path -> /data
# det_tiff1_file_name -> test_layer000007
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 61
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> /data
# det_hdf1_file_name -> test_layer000007
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 61
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 3
# A_shutter -> close
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
#   Read ['det']
# ================================== Close Run ===================================
# det_cam1_frame_type -> 1
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 10.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9413706076489998
# psofly_taxi -> Taxi
# det_cam1_num_images -> 51
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# det_cam1_frame_type -> 3
# A_shutter -> close
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
#   Read ['det']
# ================================== Close Run ===================================
# ================================== Close Run ===================================
# ffstage_ky -> 6.0
# =================================== Open Run ===================================
# det_tiff1_file_path -> /data
# det_tiff1_file_name -> test_layer000008
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 61
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> /data
# det_hdf1_file_name -> test_layer000008
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 61
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 3
# A_shutter -> close
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
#   Read ['det']
# ================================== Close Run ===================================
# det_cam1_frame_type -> 1
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 10.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9413706076489998
# psofly_taxi -> Taxi
# det_cam1_num_images -> 51
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# det_cam1_frame_type -> 3
# A_shutter -> close
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
#   Read ['det']
# ================================== Close Run ===================================
# ================================== Close Run ===================================
# ffstage_ky -> 6.5
# =================================== Open Run ===================================
# det_tiff1_file_path -> /data
# det_tiff1_file_name -> test_layer000009
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 61
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> /data
# det_hdf1_file_name -> test_layer000009
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 61
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 3
# A_shutter -> close
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
#   Read ['det']
# ================================== Close Run ===================================
# det_cam1_frame_type -> 1
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 10.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9413706076489998
# psofly_taxi -> Taxi
# det_cam1_num_images -> 51
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# det_cam1_frame_type -> 3
# A_shutter -> close
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
#   Read ['det']
# ================================== Close Run ===================================
# ================================== Close Run ===================================
# ffstage_ky -> 7.0
# =================================== Open Run ===================================
# det_tiff1_file_path -> /data
# det_tiff1_file_name -> test_layer000010
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 61
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> /data
# det_hdf1_file_name -> test_layer000010
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 61
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 3
# A_shutter -> close
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
#   Read ['det']
# ================================== Close Run ===================================
# det_cam1_frame_type -> 1
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PG1
# det_tiff1_nd_array_port -> PG1
# psofly_start -> 0.0
# psofly_end -> 10.0
# psofly_scan_delta -> 0.2
# psofly_slew_speed -> 1.9413706076489998
# psofly_taxi -> Taxi
# det_cam1_num_images -> 51
# det_cam1_trigger_mode -> Overlapped
# psofly_fly -> Fly
# ================================== Close Run ===================================
# det_cam1_frame_type -> 3
# A_shutter -> close
# =================================== Open Run ===================================
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Internal
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
#   Read ['det']
# ================================== Close Run ===================================
# ================================== Close Run ===================================

# %%
from epics import caget, caget_many

# %%
caget('S:IOC:timeOfDayForm1SI')
# Out:
# 'July 05, 2020 16:00:38'

# %%
caget('OPS:message3')
# Out:
# '0+24x1 RHB, 120 second Top-up'

# %%
pvs = [
"1idPG4:cam1:Manufacturer_RBV",   
"1idPG4:cam1:Model_RBV",          
"1idPG4:cam1:SerialNumber_RBV",   
"1idPG4:cam1:FirmwareVersion_RBV",
"1idPG4:cam1:SDKVersion_RBV",     
"1idPG4:cam1:DriverVersion_RBV",  
"1idPG4:cam1:ADCoreVersion_RBV",  
"1idPG4:cam1:AcquireTime",        
"1idPG4:cam1:AcquirePeriod",      
"1idPG4:cam1:FrameRateValAbs",    
"1idPG4:cam1:FrameRateOnOff_RBV", 
"1idPG4:cam1:Gain",               
"1idPG4:cam1:DataType_RBV",       
"1idPG4:cam1:ArrayCounter_RBV",   
"1idPG4:cam1:TemperatureActual",  
"1idPG4:cam1:FrameType",          
"1idPG4:HDF1:FileName",           
"1idPG4:HDF1:FullFileName_RBV",   
"1idPG4:HDF1:FilePath_RBV",       
"1idPG4:HDF1:PluginType_RBV" ,    
"S:IOC:timeOfDayForm1SI",         
"S:IOC:timeOfDayForm1SI" ,        
"S:SRcurrentAI" ,                
"S:TopUpStatus" ,                 
"OPS:message3" , 
"1idPG4:cam1:MaxSizeX_RBV" ,
"1idPG4:cam1:MaxSizeY_RBV" ,
"1idPG4:cam1:MinX"   ,      
"1idPG4:cam1:MinY"    ,     
"1idPG4:cam1:SizeX"    ,    
"1idPG4:cam1:SizeY"     ,   
"1idPG4:cam1:BinX"       ,  
"1idPG4:cam1:BinY"        , 
]

# %%
caget_many(pvs)
# Out:
# ['Point Grey Research',
#  'Grasshopper3 GS3-U3-23S6M',
#  '19343560',
#  '2.30.3.0',
#  '2.9.3',
#  '2.9.0',
#  '3.9.0',
#  0.5,
#  0.509917566870161,
#  30.0,
#  1,
#  1.0,
#  3,
#  2242,
#  54.950000000000045,
#  3,
#  array([116, 101, 115, 116,  50,  48,  50,  48,  95,  50,   0], dtype=uint8),
#  array([ 47, 104, 111, 109, 101,  47,  98, 101,  97, 109, 115,  47,  83,
#          54,  72,  69,  68,  77,  47, 100,  97, 116,  97,  47, 115, 115,
#         100,  47, 116, 101, 115, 116,  95, 112, 114, 101,  50,  48,  50,
#          48,  45,  50,  47, 116, 101, 115, 116,  50,  48,  50,  48,  95,
#          50,  95,  48,  48,  48,  48,  48,  55,  46, 104, 100, 102,   0],
#        dtype=uint8),
#  array([ 47, 104, 111, 109, 101,  47,  98, 101,  97, 109, 115,  47,  83,
#          54,  72,  69,  68,  77,  47, 100,  97, 116,  97,  47, 115, 115,
#         100,  47, 116, 101, 115, 116,  95, 112, 114, 101,  50,  48,  50,
#          48,  45,  50,  47,   0], dtype=uint8),
#  'NDFileHDF5 ver1.10.1',
#  'July 05, 2020 16:12:28',
#  'July 05, 2020 16:12:28',
#  102.01807952160932,
#  1,
#  '0+24x1 RHB, 120 second Top-up',
#  1920,
#  1200,
#  0,
#  0,
#  1920,
#  1200,
#  1,
#  1]

# %%
# expose internal RunEngine
RE = testexp.RE

# setup the Metadata as before
RE.md['beamline_id'] = 'APS 6'
RE.md['versions'] = {}
RE.md['versions']['apstools'] = apstools.__version__
RE.md['versions']['bluesky'] = bluesky.__version__
RE.md['versions']['databroker'] = databroker.__version__
RE.md['versions']['matplotlib'] = matplotlib.__version__
RE.md['versions']['numpy'] = np.__version__
RE.md['versions']['ophyd'] = ophyd.__version__
RE.md['SESSION_STARTED'] = datetime.isoformat(datetime.now(), " ")

# %%
scan_cfg = 'seisidd/config/scan_template.yml'

# %%
# summarize plan
testexp.dryrun(scan_cfg)

# %%
RE(scan_cfg)

# %%
det = testexp.tomo_det

# %%
det.cam.acquire_time.put(5)

# %%
det.cam.acquire_period.put(4)

# %% [markdown]
# # Overview
#
# Testing
#
# * HDF5 output with Retiga
# * Control of the shutter

# %% [markdown]
# # Hardware definition
#
# * Retiga detector
# * Aerotech stage
# * 6IDD shutter

# %%
# workaround, not necessary in user production
import sys
sys.path.insert(0,'../../beamline/dev/jupyter-ht-hedm/')

# %%
from seisidd.devices.detectors import RetigaDetectorCam6IDD
from seisidd.devices.detectors import HDF5Plugin6IDD

from ophyd   import AreaDetector
from ophyd   import ADComponent
from ophyd   import SingleTrigger
from ophyd   import ProcessPlugin
from ophyd   import TIFFPlugin
from ophyd   import TransformPlugin

# %% [markdown]
# ## Define Retiga

# %%
class RetigaDetector(SingleTrigger, AreaDetector):
    """PointGrey Detector used at 6-ID-D@APS for tomo and nf-HEDM"""

    cam1   = ADComponent(RetigaDetectorCam6IDD, suffix="cam1:" )  # camera
    proc1 = ADComponent(ProcessPlugin,         suffix="Proc1:")  # processing
    tiff1 = ADComponent(TIFFPlugin,            suffix="TIFF1:")  # tiff output
    hdf1  = ADComponent(HDF5Plugin6IDD,        suffix="HDF1:" )  # HDF5 output
    trans1 = ADComponent(TransformPlugin, suffix='Trans1:')

det = RetigaDetector('QIMAGE2:', name='det')

det.describe()
# Out:
# OrderedDict()

# %% [markdown]
# ## Define Aerotech stage

# %%
from epics import caget, caput

caput("6idhedms1:m1.SET", 0)
# Out:
# 1

# %%
from ophyd   import    Device
from ophyd   import    MotorBundle
from ophyd   import    Component as Cpt
from ophyd   import    EpicsMotor
from ophyd   import    EpicsSignal
from ophyd   import    EpicsSignalRO

class AeroRot(EpicsMotor):
    dial_readback  = Cpt(EpicsSignalRO,".DRBV", name = 'dial_readback')
    dial_value     = Cpt(EpicsSignal, ".DVAL", name = 'dial_value')
    _motor_cal_set = Cpt(EpicsSignal, ".SET",  name = '_motor_cal_set')
    _off_value     = Cpt(EpicsSignal, ".OFF",  name = '_off_value')
    
    

class StageAero(MotorBundle):
    """
    Motor stacks used for HT-HEDM

        ___________________________________
        |   fine translation:  kx,ky,kz   |
        |   fine tilt: kx_tilt, kz_tilt   |
        ===================================
        |    air-bearing rotation: rot    |
        ===================================
        |  coarse translation below Aero: | 
        |     x_base, y_base, z_base      |
        -----------------------------------

    """

    #   TODO:
    #   update with acutal PV
    ky      = Component(EpicsMotor, "6idhedm:m28", name='ky')  # y motion with kohzu stage
    kz      = Component(EpicsMotor, "6idhedm:m29", name='kz')  # z motion with kohzu stage
    kx      = Component(EpicsMotor, "6idhedm:m30", name='kx')  # x motion with kohzu stage

    rot     = Component(AeroRot, "6idhedms1:m1", name='rot')    # rotation with aero stage

# %%
tomostage = StageAero(name = 'tomostage')

tomostage.rot._motor_cal_set.put(1)
#_current_rot_pos = tomostage.rot._dialreadback.get()
tomostage.rot.dial_value.put(tomostage.rot.dial_readback.get()-360)
tomostage.rot._off_value.put(0)
tomostage.rot._motor_cal_set.put(0)

# %%
tomostage.rot._motor_cal_set.put(0)

# %% [markdown]
# ## Shutters

# %%
import bluesky
import numpy as np
from   bluesky.suspenders  import SuspendFloor
from   apstools.devices    import ApsPssShutterWithStatus
from ophyd   import    EpicsMotor


D_shutter = ApsPssShutterWithStatus(
                "PA:06ID:",                          
                "PA:06ID:STA_D_SDS_OPEN_PL",        
                name="D_shutter",
                )

suspend_shutter = SuspendFloor(D_shutter.pss_state, 1)
shutter_suspender = suspend_shutter


fast_shutter = EpicsMotor("6idhedm:m7", name='fast_shutter')

# %% [markdown]
# # Set up Tomo scan plan
#
# Due to the issue we have with the shutter controls, we cannot preform the automated scan from here.

# %%
# -- step scan
def reset():
    yield from bps.mv(tomostage.rot._motor_cal_set, 1)
    yield from bps.mv(tomostage.rot.dial_value,     tomostage.rot.dial_readback.get()-360)
    yield from bps.mv(tomostage.rot._off_value,     0)
    yield from bps.mv(tomostage.rot._motor_cal_set, 0)

    
def step_scan(cfg_tomo):
    """
    Collect projections with step motion
    """

    # TODO:
    # the fields need to be updated for 6-ID-D
    yield from bps.mv(det.hdf1.nd_array_port, 'PROC1')
    yield from bps.mv(det.tiff1.nd_array_port, 'PROC1') 
    yield from bps.mv(det.proc1.enable, 1)
    yield from bps.mv(det.proc1.enable_filter, 1)
    yield from bps.mv(det.proc1.filter_type, 'Average')
    yield from bps.mv(det.proc1.reset_filter, 1)
    yield from bps.mv(det.proc1.num_filter, cfg_tomo['n_frames'])
    yield from bps.mv(det.cam1.num_images, cfg_tomo['n_frames'])

    angs = np.arange(
        cfg_tomo['omega_start'], 
        cfg_tomo['omega_end']+cfg_tomo['omega_step']/2,
        cfg_tomo['omega_step'],
    )
    for ang in angs:
        yield from bps.checkpoint()
        if ang<-180 or ang>180:
            yield from reset()
        yield from bps.mv(tomostage.rot, ang)
        yield from bps.mv(fast_shutter, 13)
        yield from bps.trigger_and_read([det])
        yield from bps.mv(fast_shutter, 14)


# -- white field
def collect_white_field(cfg_tomo, atfront=True):
    """
    Collect white/flat field images by moving the sample out of the FOV
    """  
    # move sample out of the way
    # TODO:
    # the details and fields need to be updated for 6-ID-D
    _x = cfg_tomo['fronte_white_kx'] if atfront else cfg_tomo['back_white_kx']
    _z = cfg_tomo['fronte_white_kz'] if atfront else cfg_tomo['back_white_kz']
    yield from bps.mv(tomostage.kx, _x)  #update with correct motor name
    yield from bps.mv(tomostage.kz, _z)

    # setup detector
    # TODO:
    # actual implementation need to be for 6-ID-D
    yield from bps.mv(det.hdf1.nd_array_port, 'PROC1')
    yield from bps.mv(det.tiff1.nd_array_port, 'PROC1') 
    yield from bps.mv(det.proc1.enable, 1)
    yield from bps.mv(det.proc1.enable_filter, 1)
    yield from bps.mv(det.proc1.filter_type, 'Average')
    yield from bps.mv(det.proc1.reset_filter, 1)
    yield from bps.mv(det.proc1.num_filter, cfg_tomo['n_frames'])
    yield from bps.mv(det.cam1.trigger_mode, "Software")
    yield from bps.mv(det.cam1.image_mode, "Multiple")
    yield from bps.mv(det.cam1.num_images, cfg_tomo['n_frames']*cfg_tomo['n_white'])
    yield from bps.mv(fast_shutter, 13)
    yield from bps.trigger_and_read([det])
    yield from bps.mv(fast_shutter, 14)
    # move sample back to FOV
    # NOTE:
    # not sure is this will work or not...
    # TODO:
    #   need to update all the motor names according to StageAero
    yield from bps.mv(tomostage.kx, cfg_tomo['initial_kx'])
    yield from bps.mv(tomostage.kz, cfg_tomo['initial_kz'])
    

# -- dark field
def collect_dark_field(cfg_tomo):
    """
    Collect dark field images by close the shutter
    """
    # TODO:
    #   Need to toggle Fast shutter

    yield from bps.mv(det.hdf1.nd_array_port, 'PROC1')
    yield from bps.mv(det.tiff1.nd_array_port, 'PROC1') 
    yield from bps.mv(det.proc1.enable, 1)
    yield from bps.mv(det.proc1.enable_filter, 1)
    yield from bps.mv(det.proc1.filter_type, 'Average')
    yield from bps.mv(det.proc1.reset_filter, 1)
    yield from bps.mv(det.proc1.num_filter, cfg_tomo['n_frames'])
    yield from bps.mv(det.cam1.trigger_mode, "Software")
    yield from bps.mv(det.cam1.image_mode, "Multiple")
    yield from bps.mv(det.cam1.num_images, cfg_tomo['n_frames']*cfg_tomo['n_dark'])
    yield from bps.mv(fast_shutter, 14)
    yield from bps.trigger_and_read([det])


# -- tomo scan
def tomo_scan(cfg):
    """
    Tomography scan plan based on given configuration
    """
    tomostage.kx.move(-1.460)
    tomostage.kz.move(0.030)
    tomostage.ky.move(16.353)
    
    
    fp = cfg['output']['fp']
    fn = cfg['output']['fn']

    #########################
    ## step 0: preparation ##
    #########################
    acquire_time   = cfg['tomo']['acquire_time']
    acquire_period = cfg['tomo']['acquire_period']
    n_white        = cfg['tomo']['n_white']
    n_dark         = cfg['tomo']['n_dark']
    angs = np.arange(
        cfg['tomo']['omega_start'], 
        cfg['tomo']['omega_end']+cfg['tomo']['omega_step']/2,
        cfg['tomo']['omega_step'],
    )
    n_projections = len(angs)
    cfg['tomo']['n_projections'] = n_projections
    cfg['tomo']['total_images']  = n_white + n_projections + n_white + n_dark


    # calculate slew speed for fly scan
    # https://github.com/decarlof/tomo2bm/blob/master/flir/libs/aps2bm_lib.py
    # TODO: considering blue pixels, use 2BM code as ref

    # need to make sure that the sample out position is the same for both front and back
    x0, z0 = tomostage.kx.position, tomostage.kz.position
    dfx, dfz = cfg['tomo']['sample_out_position']['kx'], cfg['tomo']['sample_out_position']['kz']
    rotang = np.radians(cfg['tomo']['omega_end']-cfg['tomo']['omega_start'])
    rotm = np.array([[ np.cos(rotang), np.sin(rotang)],
                        [-np.sin(rotang), np.cos(rotang)]])
    dbxz = np.dot(rotm, np.array([dfx, dfz]))
    dbx = dbxz[0] if abs(dbxz[0]) > 1e-8 else 0.0
    dbz = dbxz[1] if abs(dbxz[1]) > 1e-8 else 0.0
    # now put the value to dict
    cfg['tomo']['initial_kx']       = x0
    cfg['tomo']['initial_kz']       = z0
    cfg['tomo']['fronte_white_kx']  = x0 + dfx
    cfg['tomo']['fronte_white_kz']  = z0 + dfz
    cfg['tomo']['back_white_kx']    = x0 + dbx
    cfg['tomo']['back_white_kz']    = z0 + dbz

    ###############################################
    ## step 0.9: print out the cfg for user info ##
    ###############################################   
    caput("QIMAGE2:TIFF1:AutoSave", 1)
    @bpp.stage_decorator([det])
    @bpp.run_decorator()
    def scan_closure():
        # TODO:
        #   Somewhere we need to check the light status
        # open shutter for beam

        yield from bps.install_suspender(shutter_suspender)
        # config output
        for me in [det.tiff1, det.hdf1]:
            yield from bps.mv(me.file_path, fp)
            yield from bps.mv(me.file_name, fn)
            yield from bps.mv(me.file_write_mode, 2)
            yield from bps.mv(me.num_capture, cfg['tomo']['total_images'])
            yield from bps.mv(me.file_template, ".".join([r"%s%s_%06d",cfg['output']['type'].lower()]))    

        if cfg['output']['type'] in ['tif', 'tiff']:
            yield from bps.mv(det.tiff1.enable, 1)
            yield from bps.mv(det.tiff1.capture, 1)
            yield from bps.mv(det.hdf1.enable, 0)
        elif cfg['output']['type'] in ['hdf', 'hdf1', 'hdf5']:
            yield from bps.mv(det.tiff1.enable, 0)
            yield from bps.mv(det.hdf1.enable, 1)
            yield from bps.mv(det.hdf1.capture, 1)
        else:
            raise ValueError(f"Unsupported output type {cfg['output']['type']}")
        
#         # open main shutter
#         yield from bps.mv(D_shutter, "open")

        # collect front white field
        yield from bps.mv(det.cam1.frame_type, 0)  # for HDF5 dxchange data structure
        yield from collect_white_field(cfg['tomo'], atfront=True)

        # collect projections
        yield from bps.mv(det.cam1.frame_type, 1)  # for HDF5 dxchange data structure
        if cfg['tomo']['type'].lower() == 'step':
            # setting acquire_time and acquire_period
            yield from bps.mv(det.cam1.acquire_time, acquire_time)
            yield from bps.mv(det.cam1.acquire_period, acquire_period)
            # run step_scan
            yield from step_scan(cfg['tomo'])
        else:
            raise ValueError(f"Unsupported scan type: {cfg['tomo']['type']}")

        # collect back white field
        yield from bps.mv(det.cam1.frame_type, 2)  # for HDF5 dxchange data structure
        yield from collect_white_field(cfg['tomo'], atfront=False)

        # collect back dark field
        yield from bps.mv(det.cam1.frame_type, 3)  # for HDF5 dxchange data structure

#         # TODO: no shutter available for Sim testing
#         yield from bps.remove_suspender(shutter_suspender)
#         yield from bps.mv(D_shutter, "close")
#         yield from bps.mv(fast_shutter, 1)

        yield from collect_dark_field(cfg['tomo'])
        
        yield from bps.mv(det_mtr_x, 50)
        yield from bps.mv(tomostage.ky, 6.0)

    return (yield from scan_closure())

# %% [markdown]
# ## Setup RunEngine

# %%
from bluesky.callbacks.best_effort import BestEffortCallback
from bluesky.simulators import summarize_plan
import bluesky.preprocessors as bpp
import bluesky.plan_stubs as bps

RE = bluesky.RunEngine({})
RE.subscribe(BestEffortCallback())
# Out:
# 0

# %%
cfg_tomo = {
    'type':    'step',
    'n_white': 5,
    'n_dark':  5,
    'sample_out_position': {
        'kx':  -3,
        'kz':   0,
    },
    'acquire_time':   0.5,
    'acquire_period': 1.0, 
    'omega_step':     0.1,
    'omega_start':    -180,
    'omega_end':       35820,
    'n_frames':       1,   
}

cfg_output = {
    'fn':          'HEA1_3',
    'fp':          'Q:\\\\s6idd_dec19\\tomo_HEA1_3\\' ,  # match the ff scan HEA_3
    'type':        'tif',  
}

cfg = {
    'tomo': cfg_tomo,
    'output': cfg_output,
}

# %%
summarize_plan(tomo_scan(cfg))
# Out:
# =================================== Open Run ===================================
# det_tiff1_file_path -> Q:\\s6idd_dec19\tomo_HEA1_3\
# det_tiff1_file_name -> HEA1_3
# det_tiff1_file_write_mode -> 2
# det_tiff1_num_capture -> 360016
# det_tiff1_file_template -> %s%s_%06d.tif
# det_hdf1_file_path -> Q:\\s6idd_dec19\tomo_HEA1_3\
# det_hdf1_file_name -> HEA1_3
# det_hdf1_file_write_mode -> 2
# det_hdf1_num_capture -> 360016
# det_hdf1_file_template -> %s%s_%06d.tif
# det_tiff1_enable -> 1
# det_tiff1_capture -> 1
# det_hdf1_enable -> 0
# det_cam1_frame_type -> 0
# tomostage_kx -> -4.460000000000001
# tomostage_kz -> 0.03000000000000111
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_enable_filter -> 1
# det_proc1_filter_type -> Average
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_trigger_mode -> Software
# det_cam1_image_mode -> Multiple
# det_cam1_num_images -> 5
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_kx -> -1.4600000000000009
# tomostage_kz -> 0.03000000000000111
# det_cam1_frame_type -> 1
# det_cam1_acquire_time -> 0.5
# det_cam1_acquire_period -> 1.0
# det_hdf1_nd_array_port -> PROC1
# det_tiff1_nd_array_port -> PROC1
# det_proc1_enable -> 1
# det_proc1_enable_filter -> 1
# det_proc1_filter_type -> Average
# det_proc1_reset_filter -> 1
# det_proc1_num_filter -> 1
# det_cam1_num_images -> 1
# tomostage_rot -> -180.0
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -179.9
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -179.8
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -179.70000000000002
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -179.60000000000002
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -179.50000000000003
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -179.40000000000003
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -179.30000000000004
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -179.20000000000005
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -179.10000000000005
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -179.00000000000006
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -178.90000000000006
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -178.80000000000007
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -178.70000000000007
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -178.60000000000008
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -178.50000000000009
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -178.4000000000001
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -178.3000000000001
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -178.2000000000001
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -178.1000000000001
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -178.0000000000001
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -177.90000000000012
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -177.80000000000013
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -177.70000000000013
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -177.60000000000014
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -177.50000000000014
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -177.40000000000015
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -177.30000000000015
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -177.20000000000016
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -177.10000000000016
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -177.00000000000017
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -176.90000000000018
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -176.80000000000018
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -176.7000000000002
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -176.6000000000002
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -176.5000000000002
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -176.4000000000002
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -176.3000000000002
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -176.20000000000022
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -176.10000000000022
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -176.00000000000023
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -175.90000000000023
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -175.80000000000024
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -175.70000000000024
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -175.60000000000025
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -175.50000000000026
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -175.40000000000026
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -175.30000000000027
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -175.20000000000027
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -175.10000000000028
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -175.00000000000028
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -174.9000000000003
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -174.8000000000003
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -174.7000000000003
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -174.6000000000003
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -174.5000000000003
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -174.40000000000032
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -174.30000000000032
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -174.20000000000033
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -174.10000000000034
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -174.00000000000034
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -173.90000000000035
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -173.80000000000035
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -173.70000000000036
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -173.60000000000036
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -173.50000000000037
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -173.40000000000038
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -173.30000000000038
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -173.2000000000004
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -173.1000000000004
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -173.0000000000004
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -172.9000000000004
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -172.8000000000004
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -172.70000000000041
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -172.60000000000042
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -172.50000000000043
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -172.40000000000043
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -172.30000000000044
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -172.20000000000044
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -172.10000000000045
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -172.00000000000045
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -171.90000000000046
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -171.80000000000047
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -171.70000000000047
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -171.60000000000048
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -171.50000000000048
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -171.4000000000005
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -171.3000000000005
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -171.2000000000005
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -171.1000000000005
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -171.0000000000005
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -170.90000000000052
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -170.80000000000052
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -170.70000000000053
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -170.60000000000053
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -170.50000000000054
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -170.40000000000055
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -170.30000000000055
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -170.20000000000056
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -170.10000000000056
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -170.00000000000057
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -169.90000000000057
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -169.80000000000058
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -169.70000000000059
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -169.6000000000006
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -169.5000000000006
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -169.4000000000006
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -169.3000000000006
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -169.2000000000006
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -169.10000000000062
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -169.00000000000063
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -168.90000000000063
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -168.80000000000064
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -168.70000000000064
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -168.60000000000065
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -168.50000000000065
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -168.40000000000066
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -168.30000000000067
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -168.20000000000067
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -168.10000000000068
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -168.00000000000068
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -167.9000000000007
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -167.8000000000007
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -167.7000000000007
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -167.6000000000007
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -167.5000000000007
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -167.40000000000072
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -167.30000000000072
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -167.20000000000073
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -167.10000000000073
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -167.00000000000074
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -166.90000000000074
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -166.80000000000075
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -166.70000000000076
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -166.60000000000076
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -166.50000000000077
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -166.40000000000077
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -166.30000000000078
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -166.20000000000078
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -166.1000000000008
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -166.0000000000008
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -165.9000000000008
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -165.8000000000008
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -165.7000000000008
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -165.60000000000082
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -165.50000000000082
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -165.40000000000083
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -165.30000000000084
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -165.20000000000084
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -165.10000000000085
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -165.00000000000085
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -164.90000000000086
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -164.80000000000086
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -164.70000000000087
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -164.60000000000088
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -164.50000000000088
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -164.4000000000009
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -164.3000000000009
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -164.2000000000009
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -164.1000000000009
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -164.0000000000009
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -163.90000000000092
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -163.80000000000092
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -163.70000000000093
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -163.60000000000093
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -163.50000000000094
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -163.40000000000094
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -163.30000000000095
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -163.20000000000095
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -163.10000000000096
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -163.00000000000097
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -162.90000000000097
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -162.80000000000098
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -162.70000000000098
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -162.600000000001
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -162.500000000001
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -162.400000000001
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -162.300000000001
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -162.200000000001
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -162.10000000000102
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -162.00000000000102
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -161.90000000000103
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -161.80000000000103
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -161.70000000000104
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -161.60000000000105
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -161.50000000000105
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -161.40000000000106
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -161.30000000000106
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -161.20000000000107
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -161.10000000000107
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -161.00000000000108
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -160.90000000000109
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -160.8000000000011
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -160.7000000000011
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -160.6000000000011
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -160.5000000000011
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -160.4000000000011
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -160.30000000000112
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -160.20000000000113
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -160.10000000000113
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -160.00000000000114
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -159.90000000000114
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -159.80000000000115
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -159.70000000000115
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -159.60000000000116
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -159.50000000000117
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -159.40000000000117
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -159.30000000000118
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -159.20000000000118
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -159.1000000000012
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -159.0000000000012
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -158.9000000000012
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -158.8000000000012
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -158.7000000000012
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -158.60000000000122
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -158.50000000000122
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -158.40000000000123
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -158.30000000000123
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -158.20000000000124
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -158.10000000000124
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -158.00000000000125
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -157.90000000000126
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -157.80000000000126
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -157.70000000000127
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -157.60000000000127
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -157.50000000000128
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -157.40000000000128
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -157.3000000000013
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -157.2000000000013
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -157.1000000000013
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -157.0000000000013
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -156.9000000000013
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -156.80000000000132
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -156.70000000000132
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -156.60000000000133
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -156.50000000000134
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -156.40000000000134
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -156.30000000000135
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -156.20000000000135
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -156.10000000000136
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -156.00000000000136
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -155.90000000000137
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -155.80000000000138
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -155.70000000000138
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -155.6000000000014
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -155.5000000000014
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -155.4000000000014
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -155.3000000000014
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -155.2000000000014
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -155.10000000000142
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -155.00000000000142
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -154.90000000000143
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -154.80000000000143
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -154.70000000000144
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -154.60000000000144
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -154.50000000000145
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -154.40000000000146
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -154.30000000000146
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -154.20000000000147
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -154.10000000000147
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -154.00000000000148
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -153.90000000000148
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -153.8000000000015
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -153.7000000000015
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -153.6000000000015
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -153.5000000000015
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -153.4000000000015
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -153.30000000000152
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -153.20000000000152
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -153.10000000000153
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -153.00000000000153
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -152.90000000000154
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -152.80000000000155
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -152.70000000000155
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -152.60000000000156
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -152.50000000000156
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -152.40000000000157
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -152.30000000000157
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -152.20000000000158
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -152.1000000000016
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -152.0000000000016
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -151.9000000000016
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -151.8000000000016
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -151.7000000000016
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -151.60000000000161
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -151.50000000000162
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -151.40000000000163
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -151.30000000000163
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -151.20000000000164
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -151.10000000000164
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -151.00000000000165
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -150.90000000000165
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -150.80000000000166
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -150.70000000000167
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -150.60000000000167
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -150.50000000000168
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -150.40000000000168
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -150.3000000000017
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -150.2000000000017
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -150.1000000000017
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -150.0000000000017
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -149.9000000000017
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -149.80000000000172
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -149.70000000000172
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -149.60000000000173
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -149.50000000000173
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -149.40000000000174
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -149.30000000000175
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -149.20000000000175
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -149.10000000000176
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -149.00000000000176
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -148.90000000000177
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -148.80000000000177
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -148.70000000000178
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -148.60000000000178
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -148.5000000000018
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -148.4000000000018
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -148.3000000000018
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -148.2000000000018
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -148.1000000000018
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -148.00000000000182
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -147.90000000000182
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -147.80000000000183
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -147.70000000000184
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -147.60000000000184
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -147.50000000000185
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -147.40000000000185
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -147.30000000000186
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -147.20000000000186
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -147.10000000000187
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -147.00000000000188
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -146.90000000000188
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -146.8000000000019
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -146.7000000000019
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -146.6000000000019
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -146.5000000000019
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -146.4000000000019
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -146.30000000000192
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -146.20000000000192
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -146.10000000000193
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -146.00000000000193
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -145.90000000000194
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -145.80000000000194
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -145.70000000000195
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -145.60000000000196
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -145.50000000000196
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -145.40000000000197
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -145.30000000000197
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -145.20000000000198
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -145.10000000000198
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -145.000000000002
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -144.900000000002
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -144.800000000002
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -144.700000000002
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -144.600000000002
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -144.50000000000202
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -144.40000000000202
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -144.30000000000203
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -144.20000000000203
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -144.10000000000204
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -144.00000000000205
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -143.90000000000205
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -143.80000000000206
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -143.70000000000206
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -143.60000000000207
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -143.50000000000207
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -143.40000000000208
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -143.3000000000021
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -143.2000000000021
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -143.1000000000021
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -143.0000000000021
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -142.9000000000021
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -142.80000000000211
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -142.70000000000212
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -142.60000000000213
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -142.50000000000213
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -142.40000000000214
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -142.30000000000214
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -142.20000000000215
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -142.10000000000215
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -142.00000000000216
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -141.90000000000217
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -141.80000000000217
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -141.70000000000218
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -141.60000000000218
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -141.5000000000022
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -141.4000000000022
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -141.3000000000022
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -141.2000000000022
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -141.1000000000022
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -141.00000000000222
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -140.90000000000222
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -140.80000000000223
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -140.70000000000223
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -140.60000000000224
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -140.50000000000225
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -140.40000000000225
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -140.30000000000226
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -140.20000000000226
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -140.10000000000227
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -140.00000000000227
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -139.90000000000228
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -139.80000000000229
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -139.7000000000023
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -139.6000000000023
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -139.5000000000023
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -139.4000000000023
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -139.3000000000023
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -139.20000000000232
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -139.10000000000232
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -139.00000000000233
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -138.90000000000234
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -138.80000000000234
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -138.70000000000235
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -138.60000000000235
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -138.50000000000236
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -138.40000000000236
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -138.30000000000237
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -138.20000000000238
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -138.10000000000238
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -138.0000000000024
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -137.9000000000024
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -137.8000000000024
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -137.7000000000024
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -137.6000000000024
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -137.50000000000242
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -137.40000000000242
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -137.30000000000243
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -137.20000000000243
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -137.10000000000244
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -137.00000000000244
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -136.90000000000245
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -136.80000000000246
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -136.70000000000246
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -136.60000000000247
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -136.50000000000247
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -136.40000000000248
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -136.30000000000248
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -136.2000000000025
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -136.1000000000025
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -136.0000000000025
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -135.9000000000025
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -135.8000000000025
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -135.70000000000252
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -135.60000000000252
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -135.50000000000253
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -135.40000000000254
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -135.30000000000254
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -135.20000000000255
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -135.10000000000255
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -135.00000000000256
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -134.90000000000256
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -134.80000000000257
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -134.70000000000258
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -134.60000000000258
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -134.5000000000026
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -134.4000000000026
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -134.3000000000026
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -134.2000000000026
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -134.1000000000026
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -134.00000000000261
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -133.90000000000262
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -133.80000000000263
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -133.70000000000263
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -133.60000000000264
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -133.50000000000264
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -133.40000000000265
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -133.30000000000265
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -133.20000000000266
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -133.10000000000267
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -133.00000000000267
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -132.90000000000268
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -132.80000000000268
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -132.7000000000027
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -132.6000000000027
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -132.5000000000027
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -132.4000000000027
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -132.3000000000027
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -132.20000000000272
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -132.10000000000272
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -132.00000000000273
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -131.90000000000273
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -131.80000000000274
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -131.70000000000275
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -131.60000000000275
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -131.50000000000276
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -131.40000000000276
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -131.30000000000277
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -131.20000000000277
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -131.10000000000278
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -131.00000000000279
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -130.9000000000028
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -130.8000000000028
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -130.7000000000028
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -130.6000000000028
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -130.5000000000028
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -130.40000000000282
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -130.30000000000283
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -130.20000000000283
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -130.10000000000284
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -130.00000000000284
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -129.90000000000285
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -129.80000000000285
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -129.70000000000286
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -129.60000000000286
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -129.50000000000287
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -129.40000000000288
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -129.30000000000288
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -129.2000000000029
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -129.1000000000029
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -129.0000000000029
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -128.9000000000029
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -128.8000000000029
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -128.70000000000292
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -128.60000000000292
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -128.50000000000293
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -128.40000000000293
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -128.30000000000294
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -128.20000000000294
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -128.10000000000295
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> -128.00000000000296
# ...
# fast_shutter -> 14
# tomostage_rot -> 595.299999999956
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 595.399999999956
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 595.4999999999559
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 595.5999999999559
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 595.6999999999559
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 595.7999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 595.8999999999559
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 595.9999999999559
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 596.0999999999559
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 596.1999999999559
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 596.2999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 596.3999999999559
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 596.4999999999559
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 596.5999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 596.6999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 596.7999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 596.8999999999559
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 596.9999999999559
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 597.0999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 597.1999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 597.2999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 597.3999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 597.4999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 597.5999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 597.6999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 597.7999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 597.8999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 597.9999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 598.0999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 598.1999999999557
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 598.2999999999557
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 598.3999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 598.4999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 598.5999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 598.6999999999557
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 598.7999999999557
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 598.8999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 598.9999999999557
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 599.0999999999557
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 599.1999999999557
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 599.2999999999557
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 599.3999999999558
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 599.4999999999557
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 599.5999999999557
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 599.6999999999557
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 599.7999999999556
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 599.8999999999556
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 599.9999999999557
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 600.0999999999557
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 600.1999999999557
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 600.2999999999556
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 600.3999999999556
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 600.4999999999557
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 600.5999999999556
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 600.6999999999556
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 600.7999999999556
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 600.8999999999556
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 600.9999999999557
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 601.0999999999556
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 601.1999999999556
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 601.2999999999556
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 601.3999999999555
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 601.4999999999555
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 601.5999999999556
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 601.6999999999556
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 601.7999999999556
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 601.8999999999555
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 601.9999999999555
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 602.0999999999556
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 602.1999999999555
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 602.2999999999555
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 602.3999999999555
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 602.4999999999555
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 602.5999999999556
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 602.6999999999555
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 602.7999999999555
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 602.8999999999555
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 602.9999999999554
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 603.0999999999555
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 603.1999999999555
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 603.2999999999555
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 603.3999999999555
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 603.4999999999554
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 603.5999999999555
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 603.6999999999555
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 603.7999999999554
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 603.8999999999554
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 603.9999999999554
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 604.0999999999555
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 604.1999999999555
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 604.2999999999554
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 604.3999999999554
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 604.4999999999554
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 604.5999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 604.6999999999554
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 604.7999999999554
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 604.8999999999554
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 604.9999999999554
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 605.0999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 605.1999999999554
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 605.2999999999554
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 605.3999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 605.4999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 605.5999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 605.6999999999554
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 605.7999999999554
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 605.8999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 605.9999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 606.0999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 606.1999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 606.2999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 606.3999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 606.4999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 606.5999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 606.6999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 606.7999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 606.8999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 606.9999999999552
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 607.0999999999552
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 607.1999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 607.2999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 607.3999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 607.4999999999552
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 607.5999999999552
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 607.6999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 607.7999999999552
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 607.8999999999552
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 607.9999999999552
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 608.0999999999552
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 608.1999999999553
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 608.2999999999552
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 608.3999999999552
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 608.4999999999552
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 608.5999999999551
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 608.6999999999551
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 608.7999999999552
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 608.8999999999552
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 608.9999999999552
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 609.0999999999551
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 609.1999999999551
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 609.2999999999552
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 609.3999999999551
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 609.4999999999551
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 609.5999999999551
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 609.6999999999551
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 609.7999999999552
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 609.8999999999551
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 609.9999999999551
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 610.0999999999551
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 610.199999999955
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 610.299999999955
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 610.3999999999551
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 610.4999999999551
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 610.5999999999551
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 610.699999999955
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 610.799999999955
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 610.8999999999551
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 610.999999999955
# fast_shutter -> 13
#   Read ['det']
# fast_shutter -> 14
# tomostage_rot -> 611.099999999955
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-6314ac853dfd> in <module>
# ----> 1 summarize_plan(tomo_scan(cfg))
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/simulators.py in summarize_plan(plan)
#      70         Must yield `Msg` objects
#      71     """
# ---> 72     for msg in print_summary_wrapper(plan):
#      73         ...
#      74
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py in print_summary_wrapper(plan)
#     295         elif cmd == 'set':
#     296             print('{motor.name} -> {args[0]}'.format(motor=msg.obj,
# --> 297                                                      args=msg.args))
#     298         elif cmd == 'create':
#     299             read_cache = []
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # newlines imply flush in subprocesses
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# KeyboardInterrupt:

# %%
RE(tomo_scan(cfg))
# Out:
# Transient Scan ID: 1     Time: 2019-12-12 21:06:58
# Persistent Unique Scan ID: '6c13d243-e34b-4f6f-ba7b-babb4f2f30f6'
# /home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/epics/pv.py:110: UserWarning: The `context` kwarg for epics.get_pv() is deprecated. New PVs will _not_ be created in the requested context.
#   'The `context` kwarg for epics.get_pv() is deprecated. New PVs '
# New stream: 'primary'
# +-----------+------------+
# |   seq_num |       time |
# +-----------+------------+
# |         1 | 21:07:08.8 |
# |         2 | 21:07:52.4 |
# |         3 | 21:07:54.8 |
# |         4 | 21:07:57.2 |
# |         5 | 21:07:59.6 |
# |         6 | 21:08:02.0 |
# |         7 | 21:08:04.4 |
# |         8 | 21:08:06.8 |
# |         9 | 21:08:09.2 |
# |        10 | 21:08:11.6 |
# |        11 | 21:08:14.0 |
# |        12 | 21:08:16.4 |
# |        13 | 21:08:18.8 |
# /home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/epics/ca.py:1507: UserWarning: ca.get('6idhedm:m7.HLS') timed out after 1.00 seconds.
#   warnings.warn(msg % (name(chid), timeout))
# |        14 | 21:08:22.2 |
# |        15 | 21:08:24.6 |
# |        16 | 21:08:27.2 |
# |        17 | 21:08:29.6 |
# |        18 | 21:08:32.0 |
# |        19 | 21:08:34.4 |
# |        20 | 21:08:36.8 |
# |        21 | 21:08:39.2 |
# |        22 | 21:08:41.6 |
# |        23 | 21:08:44.0 |
# |        24 | 21:08:46.4 |
# |        25 | 21:08:48.8 |
# |        26 | 21:08:51.2 |
# |        27 | 21:08:53.6 |
# |        28 | 21:08:56.0 |
# |        29 | 21:08:58.4 |
# |        30 | 21:09:00.8 |
# |        31 | 21:09:03.2 |
# |        32 | 21:09:05.6 |
# |        33 | 21:09:08.0 |
# |        34 | 21:09:10.4 |
# |        35 | 21:09:12.8 |
# |        36 | 21:09:15.2 |
# |        37 | 21:09:17.6 |
# |        38 | 21:09:20.0 |
# |        39 | 21:09:22.4 |
# |        40 | 21:09:24.8 |
# |        41 | 21:09:27.2 |
# |        42 | 21:09:29.6 |
# |        43 | 21:09:32.0 |
# |        44 | 21:09:34.4 |
# |        45 | 21:09:36.8 |
# |        46 | 21:09:39.2 |
# |        47 | 21:09:41.6 |
# |        48 | 21:09:44.0 |
# |        49 | 21:09:46.4 |
# +-----------+------------+
# |   seq_num |       time |
# +-----------+------------+
# |        50 | 21:09:48.8 |
# |        51 | 21:09:51.2 |
# |        52 | 21:09:53.6 |
# |        53 | 21:09:56.0 |
# |        54 | 21:09:58.4 |
# |        55 | 21:10:00.8 |
# |        56 | 21:10:03.2 |
# |        57 | 21:10:05.6 |
# |        58 | 21:10:08.0 |
# |        59 | 21:10:10.4 |
# |        60 | 21:10:12.8 |
# |        61 | 21:10:15.3 |
# |        62 | 21:10:17.9 |
# |        63 | 21:10:20.5 |
# |        64 | 21:10:23.1 |
# |        65 | 21:10:25.5 |
# |        66 | 21:10:28.0 |
# |        67 | 21:10:30.3 |
# |        68 | 21:10:32.8 |
# |        69 | 21:10:35.3 |
# |        70 | 21:10:37.7 |
# |        71 | 21:10:40.2 |
# |        72 | 21:10:42.7 |
# |        73 | 21:10:45.1 |

# %%
from epics import caput    
    
caput("QIMAGE2:TIFF1:AutoSave", 0)

# %%
RE.abort()
# Out:
# Aborting: running cleanup and marking exit_status as 'abort'...
# +-----------+------------+
# generator tomo_scan ['6c13d243'] (scan num: 1)
#
#
#
# [E 08:51:45.334 run_engine:1469] Run aborted
#     Traceback (most recent call last):
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py", line 1345, in _run
#         msg = self._plan_stack[-1].send(resp)
#       File "<ipython-input-42-35bc7e3791a6>", line 208, in tomo_scan
#         return (yield from scan_closure())
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py", line 1043, in dec_inner
#         return (yield from plan)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 940, in stage_wrapper
#         return (yield from finalize_wrapper(inner(), unstage_devices()))
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 501, in finalize_wrapper
#         ret = yield from plan
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 938, in inner
#         return (yield from plan)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py", line 1043, in dec_inner
#         return (yield from plan)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 327, in run_wrapper
#         else_plan=close_run)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 563, in contingency_wrapper
#         ret = yield from plan
#       File "<ipython-input-42-35bc7e3791a6>", line 187, in scan_closure
#         yield from step_scan(cfg['tomo'])
#       File "<ipython-input-42-35bc7e3791a6>", line 25, in step_scan
#         yield from bps.mv(tomostage.rot, ang)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/plan_stubs.py", line 251, in mv
#         yield Msg('wait', None, group=group)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py", line 1322, in _run
#         stashed_exception or resp)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py", line 118, in <genexpr>
#         gen = (msg for msg in gen)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py", line 1322, in _run
#         stashed_exception or resp)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py", line 123, in single_gen
#         def single_gen(msg):
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py", line 1322, in _run
#         stashed_exception or resp)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py", line 123, in single_gen
#         def single_gen(msg):
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py", line 1322, in _run
#         stashed_exception or resp)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py", line 139, in single_gen
#         return (yield msg)
#     bluesky.utils.RequestAbort
# ('6c13d243-e34b-4f6f-ba7b-babb4f2f30f6',)

# %% [markdown]
# The aerotech somehow ending up in the negative range, taking out the imaging part and just continously rotating the motor.

# %%
def dmmmy_step_scan(cfg_tomo):
    """rotate aero tech without triggering detector"""
    angs = np.arange(
        cfg_tomo['omega_start'], 
        cfg_tomo['omega_end']+cfg_tomo['omega_step']/2,
        cfg_tomo['omega_step'],
    )
    for ang in angs:
        yield from bps.checkpoint()
        yield from bps.mv(tomostage.rot, ang)
        yield from bps.mv(fast_shutter, 13)
        yield from bps.sleep(0.5)  # mimicing image acquisition
        yield from bps.mv(fast_shutter, 14)

def test_aerotech_slipring(cfg):
    """
    Monitoring the position while contiously rotating aerotech
    """
    
    tomostage.kx.move(-1.460)
    tomostage.kz.move(0.030)
    tomostage.ky.move(16.353)
    
    
    fp = cfg['output']['fp']
    fn = cfg['output']['fn']

    #########################
    ## step 0: preparation ##
    #########################
    acquire_time   = cfg['tomo']['acquire_time']
    acquire_period = cfg['tomo']['acquire_period']
    n_white        = cfg['tomo']['n_white']
    n_dark         = cfg['tomo']['n_dark']
    angs = np.arange(
        cfg['tomo']['omega_start'], 
        cfg['tomo']['omega_end']+cfg['tomo']['omega_step']/2,
        cfg['tomo']['omega_step'],
    )
    n_projections = len(angs)
    cfg['tomo']['n_projections'] = n_projections
    cfg['tomo']['total_images']  = n_white + n_projections + n_white + n_dark
    
    # calculate slew speed for fly scan
    # https://github.com/decarlof/tomo2bm/blob/master/flir/libs/aps2bm_lib.py
    # TODO: considering blue pixels, use 2BM code as ref

    # need to make sure that the sample out position is the same for both front and back
    x0, z0 = tomostage.kx.position, tomostage.kz.position
    dfx, dfz = cfg['tomo']['sample_out_position']['kx'], cfg['tomo']['sample_out_position']['kz']
    rotang = np.radians(cfg['tomo']['omega_end']-cfg['tomo']['omega_start'])
    rotm = np.array([[ np.cos(rotang), np.sin(rotang)],
                        [-np.sin(rotang), np.cos(rotang)]])
    dbxz = np.dot(rotm, np.array([dfx, dfz]))
    dbx = dbxz[0] if abs(dbxz[0]) > 1e-8 else 0.0
    dbz = dbxz[1] if abs(dbxz[1]) > 1e-8 else 0.0
    # now put the value to dict
    cfg['tomo']['initial_kx']       = x0
    cfg['tomo']['initial_kz']       = z0
    cfg['tomo']['fronte_white_kx']  = x0 + dfx
    cfg['tomo']['fronte_white_kz']  = z0 + dfz
    cfg['tomo']['back_white_kx']    = x0 + dbx
    cfg['tomo']['back_white_kz']    = z0 + dbz
    
    @bpp.run_decorator()
    def scan_closure():
        # config output
        if cfg['tomo']['type'].lower() == 'step':
            yield from dmmmy_step_scan(cfg['tomo'])
        else:
            raise ValueError(f"Unsupported scan type: {cfg['tomo']['type']}")

        # restore position
        yield from bps.mv(det_mtr_x, 50)
        yield from bps.mv(tomostage.ky, 6.0)

    return (yield from scan_closure())

# %%
from bluesky.callbacks import LiveTable

# %%
cfg_tomo_aerotech_test = {
    'type':    'step',
    'n_white': 5,
    'n_dark':  5,
    'sample_out_position': {
        'kx':  -3,
        'kz':   0,
    },
    'acquire_time':   0.5,
    'acquire_period': 1.0, 
    'omega_step':     0.1,
    'omega_start':    -180,
    'omega_end':       35820,
    'n_frames':       1,   
}

cfg_output = {
    'fn':          'HEA1_3',
    'fp':          'Q:\\\\s6idd_dec19\\tomo_HEA1_3\\' ,  # match the ff scan HEA_3
    'type':        'tif',  
}

cfg = {
    'tomo': cfg_tomo,
    'output': cfg_output,
}

# %%
RE(test_aerotech_slipring(cfg_tomo_aerotech_test), LiveTable([tomostage.rot]))
# Out:
# At least one suspender has tripped. The plan will begin when all suspenders are ready. Justification:
#     1. Signal D_shutter_pss_state = 0 is below 1
#
# Suspending... To get to the prompt, hit Ctrl-C twice to pause.
# A 'deferred pause' has been requested. The RunEngine will pause at the next checkpoint. To pause immediately, hit Ctrl+C again in the next 10 seconds.
# Deferred pause acknowledged. Continuing to checkpoint.
# trying a second time
# Pausing...
# ---------------------------------------------------------------------------
# RunEngineInterrupted                      Traceback (most recent call last)
# <ipython-input-51-542e5af405cd> in <module>
# ----> 1 RE(test_aerotech_slipring(cfg_tomo_aerotech_test), LiveTable([tomostage.rot]))
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in __call__(self, *args, **metadata_kw)
#     794
#     795         if self._interrupted:
# --> 796             raise RunEngineInterrupted(self.pause_msg) from None
#     797
#     798         return tuple(self._run_start_uids)
#
# RunEngineInterrupted:
# Your RunEngine is entering a paused state. These are your options for changing
# the state of the RunEngine:
#
# RE.resume()    Resume the plan.
# RE.abort()     Perform cleanup, then kill plan. Mark exit_stats='aborted'.
# RE.stop()      Perform cleanup, then kill plan. Mark exit_status='success'.
# RE.halt()      Emergency Stop: Do not perform cleanup --- just stop.

# %%
RE.remove_suspender(shutter_suspender)

# %%
RE(test_aerotech_slipring(cfg_tomo_aerotech_test), LiveTable([tomostage.rot]))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-53-542e5af405cd> in <module>
# ----> 1 RE(test_aerotech_slipring(cfg_tomo_aerotech_test), LiveTable([tomostage.rot]))
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in __call__(self, *args, **metadata_kw)
#     738         # If we are in the wrong state, raise.
#     739         if not self._state.is_idle:
# --> 740             raise RuntimeError("The RunEngine is in a %s state" % self._state)
#     741
#     742         futs = []
#
# RuntimeError: The RunEngine is in a paused state

# %%
RE.abort()
# Out:
# Aborting: running cleanup and marking exit_status as 'abort'...
# [E 09:08:10.794 run_engine:1469] Run aborted
#     Traceback (most recent call last):
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py", line 1322, in _run
#         stashed_exception or resp)
#       File "<ipython-input-48-bccca591d294>", line 15, in test_aerotech_slipring
#         def test_aerotech_slipring(cfg):
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py", line 1322, in _run
#         stashed_exception or resp)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py", line 139, in single_gen
#         return (yield msg)
#     bluesky.utils.RequestAbort
# ()

# %%
RE(test_aerotech_slipring(cfg_tomo_aerotech_test), LiveTable([tomostage.rot]))
# Out:
# [E 09:08:18.122 run_engine:1477] Run aborted
#     Traceback (most recent call last):
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py", line 1345, in _run
#         msg = self._plan_stack[-1].send(resp)
#       File "<ipython-input-48-bccca591d294>", line 25, in test_aerotech_slipring
#         fp = cfg['output']['fp']
#     KeyError: 'output'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-542e5af405cd> in <module>
# ----> 1 RE(test_aerotech_slipring(cfg_tomo_aerotech_test), LiveTable([tomostage.rot]))
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in __call__(self, *args, **metadata_kw)
#     791             self._task_fut.add_done_callback(set_blocking_event)
#     792
# --> 793         self._resume_task(init_func=_build_task)
#     794
#     795         if self._interrupted:
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in _resume_task(self, init_func)
#     915                     if (exc is not None
#     916                             and not isinstance(exc, _RunEnginePanic)):
# --> 917                         raise exc
#     918
#     919     def install_suspender(self, suspender):
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in _run(self)
#    1476             exit_reason = str(err)
#    1477             self.log.exception("Run aborted")
# -> 1478             raise err
#    1479         finally:
#    1480             if not exit_reason:
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in _run(self)
#    1343                     else:
#    1344                         try:
# -> 1345                             msg = self._plan_stack[-1].send(resp)
#    1346                         # We have exhausted the top generator
#    1347                         except StopIteration:
#
# <ipython-input-48-bccca591d294> in test_aerotech_slipring(cfg)
#      23
#      24
# ---> 25     fp = cfg['output']['fp']
#      26     fn = cfg['output']['fn']
#      27
#
# KeyError: 'output'

# %%
cfg_tomo = {
    'type':    'step',
    'n_white': 5,
    'n_dark':  5,
    'sample_out_position': {
        'kx':  -3,
        'kz':   0,
    },
    'acquire_time':   0.5,
    'acquire_period': 1.0, 
    'omega_step':     0.1,
    'omega_start':    -180,
    'omega_end':       35820,
    'n_frames':       1,   
}

cfg_output = {
    'fn':          'HEA1_3',
    'fp':          'Q:\\\\s6idd_dec19\\tomo_HEA1_3\\' ,  # match the ff scan HEA_3
    'type':        'tif',  
}

cfg_aerotech_test = {
    'tomo': cfg_tomo,
    'output': cfg_output,
}

# %%
RE(test_aerotech_slipring(cfg_aerotech_test), LiveTable([tomostage.rot]))
# Out:
# Transient Scan ID: 2     Time: 2019-12-13 09:09:53
# Persistent Unique Scan ID: '7ad88964-01f3-4257-b366-8a830eb71a4a'
# A 'deferred pause' has been requested. The RunEngine will pause at the next checkpoint. To pause immediately, hit Ctrl+C again in the next 10 seconds.Deferred pause acknowledged. Continuing to checkpoint.
#
# trying a second time
# Pausing...
# ---------------------------------------------------------------------------
# RunEngineInterrupted                      Traceback (most recent call last)
# <ipython-input-58-edeea4b3b900> in <module>
# ----> 1 RE(test_aerotech_slipring(cfg_aerotech_test), LiveTable([tomostage.rot]))
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in __call__(self, *args, **metadata_kw)
#     794
#     795         if self._interrupted:
# --> 796             raise RunEngineInterrupted(self.pause_msg) from None
#     797
#     798         return tuple(self._run_start_uids)
#
# RunEngineInterrupted:
# Your RunEngine is entering a paused state. These are your options for changing
# the state of the RunEngine:
#
# RE.resume()    Resume the plan.
# RE.abort()     Perform cleanup, then kill plan. Mark exit_stats='aborted'.
# RE.stop()      Perform cleanup, then kill plan. Mark exit_status='success'.
# RE.halt()      Emergency Stop: Do not perform cleanup --- just stop.

# %%
RE.abort()
# Out:
# Aborting: running cleanup and marking exit_status as 'abort'...
#
#
#
# generator test_aerotech_slipring ['7ad88964'] (scan num: 2)
# [E 09:21:48.306 run_engine:1469] Run aborted
#     Traceback (most recent call last):
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py", line 1345, in _run
#         msg = self._plan_stack[-1].send(resp)
#       File "<ipython-input-48-bccca591d294>", line 77, in test_aerotech_slipring
#         return (yield from scan_closure())
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py", line 1043, in dec_inner
#         return (yield from plan)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 327, in run_wrapper
#         else_plan=close_run)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 563, in contingency_wrapper
#         ret = yield from plan
#       File "<ipython-input-48-bccca591d294>", line 69, in scan_closure
#         yield from dmmmy_step_scan(cfg['tomo'])
#       File "<ipython-input-48-bccca591d294>", line 12, in dmmmy_step_scan
#         yield from bps.sleep(0.5)  # mimicing image acquisition
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/plan_stubs.py", line 353, in sleep
#         return (yield Msg('sleep', None, time))
#     bluesky.utils.RequestAbort
# ('7ad88964-01f3-4257-b366-8a830eb71a4a',)

# %%
tomostage.kx.describe()
# Out:
# OrderedDict([('tomostage_kx',
#               {'source': 'PV:6idhedm:m30.RBV',
#                'dtype': 'number',
#                'shape': [],
#                'precision': 5,
#                'units': 'degrees',
#                'lower_ctrl_limit': -9.459,
#                'upper_ctrl_limit': 9.940999999999999}),
#              ('tomostage_kx_user_setpoint',
#               {'source': 'PV:6idhedm:m30.VAL',
#                'dtype': 'number',
#                'shape': [],
#                'precision': 5,
#                'units': 'degrees',
#                'lower_ctrl_limit': -9.459,
#                'upper_ctrl_limit': 9.940999999999999})])

# %%
mtrkx = tomostage.kx

# %%
from epics import caget, caput

caget("6idhedm:m30.DVAL")
# Out:
# -1.7009999999999992

# %%
tomostage.rot.
# Out:
# ['user_offset', 'user_offset_dir', 'velocity', 'acceleration', 'motor_egu']

# %%
def reset():
    yield from bps.mv(tomostage.rot._motor_cal_set, 1)
    yield from bps.mv(tomostage.rot.dial_value,     tomostage.rot.dial_readback.get()-360)
    yield from bps.mv(tomostage.rot._off_value,     0)
    yield from bps.mv(tomostage.rot._motor_cal_set, 0)

    
def dmmmy_step_scan(cfg_tomo):
    """rotate aero tech without triggering detector"""
    angs = np.arange(
        cfg_tomo['omega_start'], 
        cfg_tomo['omega_end']+cfg_tomo['omega_step']/2,
        cfg_tomo['omega_step'],
    )
    for ang in angs:
        yield from bps.checkpoint()
        yield from bps.mv(tomostage.rot, ang)
        yield from bps.mv(fast_shutter, 13)
        yield from bps.sleep(0.5)  # mimicing image acquisition
        yield from bps.mv(fast_shutter, 14)

def test_aerotech_slipring(cfg):
    """
    Monitoring the position while contiously rotating aerotech
    """
    
    tomostage.kx.move(-1.460)
    tomostage.kz.move(0.030)
    tomostage.ky.move(16.353)
    
    
    fp = cfg['output']['fp']
    fn = cfg['output']['fn']

    #########################
    ## step 0: preparation ##
    #########################
    acquire_time   = cfg['tomo']['acquire_time']
    acquire_period = cfg['tomo']['acquire_period']
    n_white        = cfg['tomo']['n_white']
    n_dark         = cfg['tomo']['n_dark']
    angs = np.arange(
        cfg['tomo']['omega_start'], 
        cfg['tomo']['omega_end']+cfg['tomo']['omega_step']/2,
        cfg['tomo']['omega_step'],
    )
    n_projections = len(angs)
    cfg['tomo']['n_projections'] = n_projections
    cfg['tomo']['total_images']  = n_white + n_projections + n_white + n_dark
    
    # calculate slew speed for fly scan
    # https://github.com/decarlof/tomo2bm/blob/master/flir/libs/aps2bm_lib.py
    # TODO: considering blue pixels, use 2BM code as ref

    # need to make sure that the sample out position is the same for both front and back
    x0, z0 = tomostage.kx.position, tomostage.kz.position
    dfx, dfz = cfg['tomo']['sample_out_position']['kx'], cfg['tomo']['sample_out_position']['kz']
    rotang = np.radians(cfg['tomo']['omega_end']-cfg['tomo']['omega_start'])
    rotm = np.array([[ np.cos(rotang), np.sin(rotang)],
                        [-np.sin(rotang), np.cos(rotang)]])
    dbxz = np.dot(rotm, np.array([dfx, dfz]))
    dbx = dbxz[0] if abs(dbxz[0]) > 1e-8 else 0.0
    dbz = dbxz[1] if abs(dbxz[1]) > 1e-8 else 0.0
    # now put the value to dict
    cfg['tomo']['initial_kx']       = x0
    cfg['tomo']['initial_kz']       = z0
    cfg['tomo']['fronte_white_kx']  = x0 + dfx
    cfg['tomo']['fronte_white_kz']  = z0 + dfz
    cfg['tomo']['back_white_kx']    = x0 + dbx
    cfg['tomo']['back_white_kz']    = z0 + dbz
    
    @bpp.run_decorator()
    def scan_closure():
        # config output
        if cfg['tomo']['type'].lower() == 'step':
            yield from dmmmy_step_scan(cfg['tomo'])
        else:
            raise ValueError(f"Unsupported scan type: {cfg['tomo']['type']}")

        # restore position
        yield from bps.mv(det_mtr_x, 50)
        yield from bps.mv(tomostage.ky, 6.0)

    return (yield from scan_closure())

def repeat(n_turns, cfg):
    for _ in range(n_turns):
        yield from test_aerotech_slipring(cfg)
        yield from reset()

# %%
cfg_tomo = {
    'type':    'step',
    'n_white': 5,
    'n_dark':  5,
    'sample_out_position': {
        'kx':  -3,
        'kz':   0,
    },
    'acquire_time':   0.5,
    'acquire_period': 1.0, 
    'omega_step':     0.1,
    'omega_start':    -180,
    'omega_end':       35820,
    'n_frames':       1,   
}

cfg_output = {
    'fn':          'HEA1_3',
    'fp':          'Q:\\\\s6idd_dec19\\tomo_HEA1_3\\' ,  # match the ff scan HEA_3
    'type':        'tif',  
}

cfg_aerotech_test = {
    'tomo': cfg_tomo,
    'output': cfg_output,
}

# %%
RE(repeat(2, cfg_aerotech_test), LiveTable([tomostage.rot]))
# Out:
# Transient Scan ID: 3     Time: 2019-12-13 12:17:27
# Persistent Unique Scan ID: '3965d15f-859b-43c8-8c81-15dc88f4e0b2'
# A 'deferred pause' has been requested. The RunEngine will pause at the next checkpoint. To pause immediately, hit Ctrl+C again in the next 10 seconds.
# Deferred pause acknowledged. Continuing to checkpoint.
# trying a second time
# Pausing...
# ---------------------------------------------------------------------------
# RunEngineInterrupted                      Traceback (most recent call last)
# <ipython-input-140-866ea302e1e0> in <module>
# ----> 1 RE(repeat(2, cfg_aerotech_test), LiveTable([tomostage.rot]))
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in __call__(self, *args, **metadata_kw)
#     794
#     795         if self._interrupted:
# --> 796             raise RunEngineInterrupted(self.pause_msg) from None
#     797
#     798         return tuple(self._run_start_uids)
#
# RunEngineInterrupted:
# Your RunEngine is entering a paused state. These are your options for changing
# the state of the RunEngine:
#
# RE.resume()    Resume the plan.
# RE.abort()     Perform cleanup, then kill plan. Mark exit_stats='aborted'.
# RE.stop()      Perform cleanup, then kill plan. Mark exit_status='success'.
# RE.halt()      Emergency Stop: Do not perform cleanup --- just stop.

# %%
RE.abort()
# Out:
# Aborting: running cleanup and marking exit_status as 'abort'...
#
#
#
# generator repeat ['3965d15f'] (scan num: 3)
# [E 12:18:35.700 run_engine:1469] Run aborted
#     Traceback (most recent call last):
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py", line 1345, in _run
#         msg = self._plan_stack[-1].send(resp)
#       File "<ipython-input-139-0f7fafc7c7de>", line 88, in repeat
#         yield from test_aerotech_slipring(cfg)
#       File "<ipython-input-139-0f7fafc7c7de>", line 84, in test_aerotech_slipring
#         return (yield from scan_closure())
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py", line 1043, in dec_inner
#         return (yield from plan)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 327, in run_wrapper
#         else_plan=close_run)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 563, in contingency_wrapper
#         ret = yield from plan
#       File "<ipython-input-139-0f7fafc7c7de>", line 76, in scan_closure
#         yield from dmmmy_step_scan(cfg['tomo'])
#       File "<ipython-input-139-0f7fafc7c7de>", line 20, in dmmmy_step_scan
#         yield from bps.mv(fast_shutter, 14)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/plan_stubs.py", line 251, in mv
#         yield Msg('wait', None, group=group)
#     bluesky.utils.RequestAbort
# ('3965d15f-859b-43c8-8c81-15dc88f4e0b2',)

# %%
cfg_tomo = {
    'type':    'step',
    'n_white': 5,
    'n_dark':  5,
    'sample_out_position': {
        'kx':  -3,
        'kz':   0,
    },
    'acquire_time':   0.5,
    'acquire_period': 1.0, 
    'omega_step':     10,
    'omega_start':    -180,
    'omega_end':       35820,
    'n_frames':       1,   
}

cfg_output = {
    'fn':          'HEA1_3',
    'fp':          'Q:\\\\s6idd_dec19\\tomo_HEA1_3\\' ,  # match the ff scan HEA_3
    'type':        'tif',  
}

cfg_aerotech_test = {
    'tomo': cfg_tomo,
    'output': cfg_output,
}

RE(repeat(2, cfg_aerotech_test), LiveTable([tomostage.rot]))
# Out:
# Transient Scan ID: 4     Time: 2019-12-13 12:19:08
# Persistent Unique Scan ID: '1c5d10ed-2847-4ac6-a208-e6e37dd466a2'
# A 'deferred pause' has been requested. The RunEngine will pause at the next checkpoint. To pause immediately, hit Ctrl+C again in the next 10 seconds.Deferred pause acknowledged. Continuing to checkpoint.
#
# trying a second time
# Pausing...
# ---------------------------------------------------------------------------
# RunEngineInterrupted                      Traceback (most recent call last)
# <ipython-input-143-41d0c20c675a> in <module>
#      26 }
#      27
# ---> 28 RE(repeat(2, cfg_aerotech_test), LiveTable([tomostage.rot]))
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in __call__(self, *args, **metadata_kw)
#     794
#     795         if self._interrupted:
# --> 796             raise RunEngineInterrupted(self.pause_msg) from None
#     797
#     798         return tuple(self._run_start_uids)
#
# RunEngineInterrupted:
# Your RunEngine is entering a paused state. These are your options for changing
# the state of the RunEngine:
#
# RE.resume()    Resume the plan.
# RE.abort()     Perform cleanup, then kill plan. Mark exit_stats='aborted'.
# RE.stop()      Perform cleanup, then kill plan. Mark exit_status='success'.
# RE.halt()      Emergency Stop: Do not perform cleanup --- just stop.

# %%
RE.abort()
# Out:
# Aborting: running cleanup and marking exit_status as 'abort'...
#
#
#
# generator repeat ['1c5d10ed'] (scan num: 4)
# [E 12:21:48.763 run_engine:1469] Run aborted
#     Traceback (most recent call last):
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py", line 1345, in _run
#         msg = self._plan_stack[-1].send(resp)
#       File "<ipython-input-139-0f7fafc7c7de>", line 88, in repeat
#         yield from test_aerotech_slipring(cfg)
#       File "<ipython-input-139-0f7fafc7c7de>", line 84, in test_aerotech_slipring
#         return (yield from scan_closure())
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py", line 1043, in dec_inner
#         return (yield from plan)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 327, in run_wrapper
#         else_plan=close_run)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 563, in contingency_wrapper
#         ret = yield from plan
#       File "<ipython-input-139-0f7fafc7c7de>", line 76, in scan_closure
#         yield from dmmmy_step_scan(cfg['tomo'])
#       File "<ipython-input-139-0f7fafc7c7de>", line 17, in dmmmy_step_scan
#         yield from bps.mv(tomostage.rot, ang)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/plan_stubs.py", line 251, in mv
#         yield Msg('wait', None, group=group)
#     bluesky.utils.RequestAbort
# ('1c5d10ed-2847-4ac6-a208-e6e37dd466a2',)

# %%
cfg_tomo = {
    'type':    'step',
    'n_white': 5,
    'n_dark':  5,
    'sample_out_position': {
        'kx':  -3,
        'kz':   0,
    },
    'acquire_time':   0.5,
    'acquire_period': 1.0, 
    'omega_step':     10,
    'omega_start':    -180,
    'omega_end':       180,
    'n_frames':       1,   
}

cfg_output = {
    'fn':          'HEA1_3',
    'fp':          'Q:\\\\s6idd_dec19\\tomo_HEA1_3\\' ,  # match the ff scan HEA_3
    'type':        'tif',  
}

cfg_aerotech_test = {
    'tomo': cfg_tomo,
    'output': cfg_output,
}

RE(repeat(2, cfg_aerotech_test), LiveTable([tomostage.rot]))
# Out:
# Transient Scan ID: 5     Time: 2019-12-13 12:22:08
# Persistent Unique Scan ID: '884353a5-03d9-4406-b589-7c77af529334'
#
#
#
# generator repeat ['884353a5'] (scan num: 5)
# [E 12:25:04.018 run_engine:1477] Run aborted
#     Traceback (most recent call last):
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py", line 1345, in _run
#         msg = self._plan_stack[-1].send(resp)
#       File "<ipython-input-139-0f7fafc7c7de>", line 88, in repeat
#         yield from test_aerotech_slipring(cfg)
#       File "<ipython-input-139-0f7fafc7c7de>", line 84, in test_aerotech_slipring
#         return (yield from scan_closure())
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py", line 1043, in dec_inner
#         return (yield from plan)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 327, in run_wrapper
#         else_plan=close_run)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 563, in contingency_wrapper
#         ret = yield from plan
#       File "<ipython-input-139-0f7fafc7c7de>", line 81, in scan_closure
#         yield from bps.mv(det_mtr_x, 50)
#     NameError: name 'det_mtr_x' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-145-3202ad8c2cfc> in <module>
#      26 }
#      27
# ---> 28 RE(repeat(2, cfg_aerotech_test), LiveTable([tomostage.rot]))
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in __call__(self, *args, **metadata_kw)
#     791             self._task_fut.add_done_callback(set_blocking_event)
#     792
# --> 793         self._resume_task(init_func=_build_task)
#     794
#     795         if self._interrupted:
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in _resume_task(self, init_func)
#     915                     if (exc is not None
#     916                             and not isinstance(exc, _RunEnginePanic)):
# --> 917                         raise exc
#     918
#     919     def install_suspender(self, suspender):
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in _run(self)
#    1476             exit_reason = str(err)
#    1477             self.log.exception("Run aborted")
# -> 1478             raise err
#    1479         finally:
#    1480             if not exit_reason:
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in _run(self)
#    1343                     else:
#    1344                         try:
# -> 1345                             msg = self._plan_stack[-1].send(resp)
#    1346                         # We have exhausted the top generator
#    1347                         except StopIteration:
#
# <ipython-input-139-0f7fafc7c7de> in repeat(n_turns, cfg)
#      86 def repeat(n_turns, cfg):
#      87     for _ in range(n_turns):
# ---> 88         yield from test_aerotech_slipring(cfg)
#      89         yield from reset()
#
# <ipython-input-139-0f7fafc7c7de> in test_aerotech_slipring(cfg)
#      82         yield from bps.mv(tomostage.ky, 6.0)
#      83
# ---> 84     return (yield from scan_closure())
#      85
#      86 def repeat(n_turns, cfg):
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py in dec_inner(*inner_args, **inner_kwargs)
#    1041                 plan = gen_func(*inner_args, **inner_kwargs)
#    1042                 plan = wrapper(plan, *args, **kwargs)
# -> 1043                 return (yield from plan)
#    1044             return dec_inner
#    1045         return dec
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py in run_wrapper(plan, md)
#     325     yield from contingency_wrapper(plan,
#     326                                    except_plan=except_plan,
# --> 327                                    else_plan=close_run)
#     328     return rs_uid
#     329
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py in contingency_wrapper(plan, except_plan, else_plan, final_plan, pause_for_debug)
#     561     cleanup = True
#     562     try:
# --> 563         ret = yield from plan
#     564     except GeneratorExit:
#     565         cleanup = False
#
# <ipython-input-139-0f7fafc7c7de> in scan_closure()
#      79
#      80         # restore position
# ---> 81         yield from bps.mv(det_mtr_x, 50)
#      82         yield from bps.mv(tomostage.ky, 6.0)
#      83
#
# NameError: name 'det_mtr_x' is not defined

# %%
def reset():
    yield from bps.mv(tomostage.rot._motor_cal_set, 1)
    yield from bps.mv(tomostage.rot.dial_value,     tomostage.rot.dial_readback.get()-360)
    yield from bps.mv(tomostage.rot._off_value,     0)
    yield from bps.mv(tomostage.rot._motor_cal_set, 0)

    
def dmmmy_step_scan(cfg_tomo):
    """rotate aero tech without triggering detector"""
    angs = np.arange(
        cfg_tomo['omega_start'], 
        cfg_tomo['omega_end']+cfg_tomo['omega_step']/2,
        cfg_tomo['omega_step'],
    )
    for ang in angs:
        yield from bps.checkpoint()
        yield from bps.mv(tomostage.rot, ang)
        yield from bps.mv(fast_shutter, 13)
        yield from bps.sleep(0.5)  # mimicing image acquisition
        yield from bps.mv(fast_shutter, 14)

def test_aerotech_slipring(cfg):
    """
    Monitoring the position while contiously rotating aerotech
    """
    
    tomostage.kx.move(-1.460)
    tomostage.kz.move(0.030)
    tomostage.ky.move(16.353)
    
    
    fp = cfg['output']['fp']
    fn = cfg['output']['fn']

    #########################
    ## step 0: preparation ##
    #########################
    acquire_time   = cfg['tomo']['acquire_time']
    acquire_period = cfg['tomo']['acquire_period']
    n_white        = cfg['tomo']['n_white']
    n_dark         = cfg['tomo']['n_dark']
    angs = np.arange(
        cfg['tomo']['omega_start'], 
        cfg['tomo']['omega_end']+cfg['tomo']['omega_step']/2,
        cfg['tomo']['omega_step'],
    )
    n_projections = len(angs)
    cfg['tomo']['n_projections'] = n_projections
    cfg['tomo']['total_images']  = n_white + n_projections + n_white + n_dark
    
    # calculate slew speed for fly scan
    # https://github.com/decarlof/tomo2bm/blob/master/flir/libs/aps2bm_lib.py
    # TODO: considering blue pixels, use 2BM code as ref

    # need to make sure that the sample out position is the same for both front and back
    x0, z0 = tomostage.kx.position, tomostage.kz.position
    dfx, dfz = cfg['tomo']['sample_out_position']['kx'], cfg['tomo']['sample_out_position']['kz']
    rotang = np.radians(cfg['tomo']['omega_end']-cfg['tomo']['omega_start'])
    rotm = np.array([[ np.cos(rotang), np.sin(rotang)],
                        [-np.sin(rotang), np.cos(rotang)]])
    dbxz = np.dot(rotm, np.array([dfx, dfz]))
    dbx = dbxz[0] if abs(dbxz[0]) > 1e-8 else 0.0
    dbz = dbxz[1] if abs(dbxz[1]) > 1e-8 else 0.0
    # now put the value to dict
    cfg['tomo']['initial_kx']       = x0
    cfg['tomo']['initial_kz']       = z0
    cfg['tomo']['fronte_white_kx']  = x0 + dfx
    cfg['tomo']['fronte_white_kz']  = z0 + dfz
    cfg['tomo']['back_white_kx']    = x0 + dbx
    cfg['tomo']['back_white_kz']    = z0 + dbz
    
    @bpp.run_decorator()
    def scan_closure():
        # config output
        if cfg['tomo']['type'].lower() == 'step':
            yield from dmmmy_step_scan(cfg['tomo'])
        else:
            raise ValueError(f"Unsupported scan type: {cfg['tomo']['type']}")

        # restore position
#         yield from bps.mv(det_mtr_x, 50)
        yield from bps.mv(tomostage.ky, 6.0)

    return (yield from scan_closure())

def repeat(n_turns, cfg):
    for _ in range(n_turns):
        yield from test_aerotech_slipring(cfg)
        yield from reset()

# %%
RE.abort()
# Out:
# ---------------------------------------------------------------------------
# TransitionError                           Traceback (most recent call last)
# <ipython-input-147-7af2a2d1869f> in <module>
# ----> 1 RE.abort()
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in abort(self, reason)
#    1098         :meth:`RunEngine.stop`
#    1099         """
# -> 1100         return self.__interrupter_helper(self._abort_coro(reason))
#    1101
#    1102     async def _abort_coro(self, reason):
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in __interrupter_helper(self, coro)
#    1180             self._resume_task()
#    1181
# -> 1182         return task.result()
#    1183
#    1184     async def _halt_coro(self):
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in _abort_coro(self, reason)
#    1102     async def _abort_coro(self, reason):
#    1103         if self._state.is_idle:
# -> 1104             raise TransitionError("RunEngine is already idle.")
#    1105         print("Aborting: running cleanup and marking "
#    1106               "exit_status as 'abort'...")
#
# TransitionError: RunEngine is already idle.

# %%
tomostage.rot._motor_cal_set.put(1)
tomostage.rot.dial_value.put(tomostage.rot.dial_readback.get()-360)
tomostage.rot._off_value.put(0)
tomostage.rot._motor_cal_set.put(0)

# %%
cfg_tomo = {
    'type':    'step',
    'n_white': 5,
    'n_dark':  5,
    'sample_out_position': {
        'kx':  -3,
        'kz':   0,
    },
    'acquire_time':   0.5,
    'acquire_period': 1.0, 
    'omega_step':     10,
    'omega_start':    -180,
    'omega_end':       180,
    'n_frames':       1,   
}

cfg_output = {
    'fn':          'HEA1_3',
    'fp':          'Q:\\\\s6idd_dec19\\tomo_HEA1_3\\' ,  # match the ff scan HEA_3
    'type':        'tif',  
}

cfg_aerotech_test = {
    'tomo': cfg_tomo,
    'output': cfg_output,
}

RE(repeat(2, cfg_aerotech_test), LiveTable([tomostage.rot]))
# Out:
# Transient Scan ID: 6     Time: 2019-12-13 12:27:19
# Persistent Unique Scan ID: '7b55db60-d885-413e-8345-218940c92f03'
#
#
#
# generator repeat ['7b55db60'] (scan num: 6)
# Transient Scan ID: 7     Time: 2019-12-13 12:33:07
# Persistent Unique Scan ID: '80530566-5bd8-4dd2-b2f0-ea75d8f210e4'
#
#
#
# generator repeat ['80530566'] (scan num: 7)
# ('7b55db60-d885-413e-8345-218940c92f03',
#  '80530566-5bd8-4dd2-b2f0-ea75d8f210e4')

# %%
RE(repeat(100, cfg_aerotech_test), LiveTable([tomostage.rot]))
# Out:
# Transient Scan ID: 8     Time: 2019-12-13 12:39:20
# Persistent Unique Scan ID: 'f78d918c-60fb-466c-b99e-2e18589b3059'
#
#
#
# generator repeat ['f78d918c'] (scan num: 8)
# Transient Scan ID: 9     Time: 2019-12-13 12:45:05
# Persistent Unique Scan ID: '62a9d0dc-bb95-4031-bc72-df33c7912556'
# /home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/epics/ca.py:1507: UserWarning: ca.get('6idhedm:m7.TDIR') timed out after 1.00 seconds.
#   warnings.warn(msg % (name(chid), timeout))
# /home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/epics/ca.py:1507: UserWarning: ca.get('6idhedm:m7.HLS') timed out after 1.00 seconds.
#   warnings.warn(msg % (name(chid), timeout))
# generator repeat ['62a9d0dc'] (scan num: 9)
# Transient Scan ID: 10     Time: 2019-12-13 12:50:54
# Persistent Unique Scan ID: '103c48d6-972e-484c-8908-5a950f5dcecb'
#
#
#
# generator repeat ['103c48d6'] (scan num: 10)
# Transient Scan ID: 11     Time: 2019-12-13 12:56:39
# Persistent Unique Scan ID: '2c9e51fd-f0f8-475f-96ed-a61458e67b07'
#
#
#
# generator repeat ['2c9e51fd'] (scan num: 11)
# Transient Scan ID: 12     Time: 2019-12-13 13:02:25
# Persistent Unique Scan ID: '3c880df0-486d-41d6-b97e-7de8d657087a'
#
#
#
# generator repeat ['3c880df0'] (scan num: 12)
# Transient Scan ID: 13     Time: 2019-12-13 13:08:12
# Persistent Unique Scan ID: '25c066db-44fd-4531-95e6-ec21087a9222'
#
#
#
# generator repeat ['25c066db'] (scan num: 13)
# Transient Scan ID: 14     Time: 2019-12-13 13:13:57
# Persistent Unique Scan ID: 'c7a9ac32-c2a2-4082-b964-f09c7d179506'
#
#
#
# generator repeat ['c7a9ac32'] (scan num: 14)
# Transient Scan ID: 15     Time: 2019-12-13 13:19:42
# Persistent Unique Scan ID: '87b1f3ca-5595-46e4-bff0-08def178cb47'
#
#
#
# generator repeat ['87b1f3ca'] (scan num: 15)
# Transient Scan ID: 16     Time: 2019-12-13 13:25:26
# Persistent Unique Scan ID: '18ab9cce-52f0-46d1-af62-60b6ff3f1971'
#
#
#
# generator repeat ['18ab9cce'] (scan num: 16)
# Transient Scan ID: 17     Time: 2019-12-13 13:31:11
# Persistent Unique Scan ID: '1c7e1ebb-bc56-4f36-bce5-5b3dd19f15bf'
#
#
#
# generator repeat ['1c7e1ebb'] (scan num: 17)
# Transient Scan ID: 18     Time: 2019-12-13 13:36:57
# Persistent Unique Scan ID: 'ccd16be0-a7eb-4f5b-938b-41fca929d5ac'
#
#
#
# generator repeat ['ccd16be0'] (scan num: 18)
# Transient Scan ID: 19     Time: 2019-12-13 13:42:43
# Persistent Unique Scan ID: '24fb69bc-3a3b-41e6-ae6b-8fafaf7046c8'
#
#
#
# generator repeat ['24fb69bc'] (scan num: 19)
# Transient Scan ID: 20     Time: 2019-12-13 13:48:29
# Persistent Unique Scan ID: '54c44b5f-56bc-4507-9af3-24adf6b51e9e'
#
#
#
# generator repeat ['54c44b5f'] (scan num: 20)
# Transient Scan ID: 21     Time: 2019-12-13 13:54:15
# Persistent Unique Scan ID: '59ddcfc2-d388-481d-b89e-78d022150e1d'
#
#
#
# generator repeat ['59ddcfc2'] (scan num: 21)
# Transient Scan ID: 22     Time: 2019-12-13 14:00:03
# Persistent Unique Scan ID: 'c60175a1-b290-45e1-ba2a-993edea510a5'
#
#
#
# generator repeat ['c60175a1'] (scan num: 22)
# Transient Scan ID: 23     Time: 2019-12-13 14:05:50
# Persistent Unique Scan ID: '6e1d05fc-89d1-4d8b-8f91-23673aca4f34'
#
#
#
# generator repeat ['6e1d05fc'] (scan num: 23)
# Transient Scan ID: 24     Time: 2019-12-13 14:11:36
# Persistent Unique Scan ID: 'ae9043fa-96ff-4791-b28e-442e40eb7e7f'
#
#
#
# generator repeat ['ae9043fa'] (scan num: 24)
# Transient Scan ID: 25     Time: 2019-12-13 14:17:23
# Persistent Unique Scan ID: 'ac1e9eef-2ea5-4113-8e97-90e19b36a0bf'
#
#
#
# generator repeat ['ac1e9eef'] (scan num: 25)
# Transient Scan ID: 26     Time: 2019-12-13 14:23:11
# Persistent Unique Scan ID: 'f6629f6e-4091-4f59-b9f1-d948d740696e'
#
#
#
# generator repeat ['f6629f6e'] (scan num: 26)
# Transient Scan ID: 27     Time: 2019-12-13 14:28:59
# Persistent Unique Scan ID: 'c9656304-d84f-4ca0-9518-5509cacab137'
#
#
#
# generator repeat ['c9656304'] (scan num: 27)
# Transient Scan ID: 28     Time: 2019-12-13 14:34:47
# Persistent Unique Scan ID: 'ae78389b-94b5-4182-b73d-593f1dbea692'
#
#
#
# generator repeat ['ae78389b'] (scan num: 28)
# Transient Scan ID: 29     Time: 2019-12-13 14:40:34
# Persistent Unique Scan ID: 'eb5d344a-f861-4345-b868-f06c42b77623'
#
#
#
# generator repeat ['eb5d344a'] (scan num: 29)
# Transient Scan ID: 30     Time: 2019-12-13 14:46:21
# Persistent Unique Scan ID: '1c48f5d6-57c0-41ee-a770-43a4bc59b7f2'
#
#
#
# generator repeat ['1c48f5d6'] (scan num: 30)
# Transient Scan ID: 31     Time: 2019-12-13 14:52:10
# Persistent Unique Scan ID: 'f9f545b2-2343-4fed-9691-f08cdd58f1af'
#
#
#
# generator repeat ['f9f545b2'] (scan num: 31)
# Transient Scan ID: 32     Time: 2019-12-13 14:57:57
# Persistent Unique Scan ID: 'e729bf52-2a6b-49e2-8485-c6dc857154e2'
#
#
#
# generator repeat ['e729bf52'] (scan num: 32)
# Transient Scan ID: 33     Time: 2019-12-13 15:03:45
# Persistent Unique Scan ID: 'cf1819ac-1cc9-48de-9109-a689dca88e42'
#
#
#
# generator repeat ['cf1819ac'] (scan num: 33)
# Transient Scan ID: 34     Time: 2019-12-13 15:09:33
# Persistent Unique Scan ID: 'cb11e651-8e38-44af-bc51-1c8d6ad2da13'
#
#
#
# generator repeat ['cb11e651'] (scan num: 34)
# Transient Scan ID: 35     Time: 2019-12-13 15:15:22
# Persistent Unique Scan ID: '9c810ac6-b8a7-4c30-b9d3-8415192bfb67'
#
#
#
# generator repeat ['9c810ac6'] (scan num: 35)
# Transient Scan ID: 36     Time: 2019-12-13 15:21:07
# Persistent Unique Scan ID: '1a7406df-c5ea-44b1-8025-0cce4a703835'
#
#
#
# generator repeat ['1a7406df'] (scan num: 36)
# Transient Scan ID: 37     Time: 2019-12-13 15:26:53
# Persistent Unique Scan ID: 'ecf23344-1a6c-4f22-8a84-6f8a043bda69'
#
#
#
# generator repeat ['ecf23344'] (scan num: 37)
# Transient Scan ID: 38     Time: 2019-12-13 15:32:40
# Persistent Unique Scan ID: 'db9bf4b4-2829-40e4-8c07-eef3682b1ea2'
#
#
#
# generator repeat ['db9bf4b4'] (scan num: 38)
# Transient Scan ID: 39     Time: 2019-12-13 15:38:25
# Persistent Unique Scan ID: '1721e3ef-955d-48d5-bd7e-ec80d412d617'
#
#
#
# generator repeat ['1721e3ef'] (scan num: 39)
# Transient Scan ID: 40     Time: 2019-12-13 15:44:11
# Persistent Unique Scan ID: 'fa3eb83d-19cf-4870-b525-74a16bf90529'
#
#
#
# generator repeat ['fa3eb83d'] (scan num: 40)
# Transient Scan ID: 41     Time: 2019-12-13 15:49:57
# Persistent Unique Scan ID: '6548db9e-33d5-4924-8292-0b934bd0bf0a'
#
#
#
# generator repeat ['6548db9e'] (scan num: 41)
# Transient Scan ID: 42     Time: 2019-12-13 15:55:43
# Persistent Unique Scan ID: '7914598c-e619-4793-84be-515d1a9be39c'
#
#
#
# generator repeat ['7914598c'] (scan num: 42)
# Transient Scan ID: 43     Time: 2019-12-13 16:01:30
# Persistent Unique Scan ID: '8810f641-5682-471c-a578-8dc71d3b09e7'
#
#
#
# generator repeat ['8810f641'] (scan num: 43)
# Transient Scan ID: 44     Time: 2019-12-13 16:07:16
# Persistent Unique Scan ID: '4926fd90-7428-4a1d-8883-357ab27c2c7a'
#
#
#
# generator repeat ['4926fd90'] (scan num: 44)
# Transient Scan ID: 45     Time: 2019-12-13 16:13:02
# Persistent Unique Scan ID: '7e9db180-3306-4c8f-bce1-ea8d4ed4f772'
#
#
#
# generator repeat ['7e9db180'] (scan num: 45)
# Transient Scan ID: 46     Time: 2019-12-13 16:18:49
# Persistent Unique Scan ID: 'be0ea960-8b14-4366-a9f7-ca47c445a863'
#
#
#
# generator repeat ['be0ea960'] (scan num: 46)
# Transient Scan ID: 47     Time: 2019-12-13 16:24:34
# Persistent Unique Scan ID: '1c4a431b-8e2f-416b-a2b2-e9e576c5dc81'
#
#
#
# generator repeat ['1c4a431b'] (scan num: 47)
# Transient Scan ID: 48     Time: 2019-12-13 16:30:19
# Persistent Unique Scan ID: 'a3fb2234-ea75-4630-ba1d-71b4d4d80d48'
#
#
#
# generator repeat ['a3fb2234'] (scan num: 48)
# Transient Scan ID: 49     Time: 2019-12-13 16:36:03
# Persistent Unique Scan ID: 'e91361f0-51f8-4ab5-b53d-1eb8f2892dda'
#
#
#
# generator repeat ['e91361f0'] (scan num: 49)
# Transient Scan ID: 50     Time: 2019-12-13 16:41:48
# Persistent Unique Scan ID: '46696952-0205-4377-8397-0961d4e3736d'
#
#
#
# generator repeat ['46696952'] (scan num: 50)
# Transient Scan ID: 51     Time: 2019-12-13 16:47:33
# Persistent Unique Scan ID: '2939b9e7-9c3a-429c-9891-2b78864d2c69'
# A 'deferred pause' has been requested. The RunEngine will pause at the next checkpoint. To pause immediately, hit Ctrl+C again in the next 10 seconds.Deferred pause acknowledged. Continuing to checkpoint.
#
# trying a second time
# Pausing...
# ---------------------------------------------------------------------------
# RunEngineInterrupted                      Traceback (most recent call last)
# <ipython-input-150-9879cb8f4805> in <module>
# ----> 1 RE(repeat(100, cfg_aerotech_test), LiveTable([tomostage.rot]))
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in __call__(self, *args, **metadata_kw)
#     794
#     795         if self._interrupted:
# --> 796             raise RunEngineInterrupted(self.pause_msg) from None
#     797
#     798         return tuple(self._run_start_uids)
#
# RunEngineInterrupted:
# Your RunEngine is entering a paused state. These are your options for changing
# the state of the RunEngine:
#
# RE.resume()    Resume the plan.
# RE.abort()     Perform cleanup, then kill plan. Mark exit_stats='aborted'.
# RE.stop()      Perform cleanup, then kill plan. Mark exit_status='success'.
# RE.halt()      Emergency Stop: Do not perform cleanup --- just stop.

# %%
RE.abort()
# Out:
# Aborting: running cleanup and marking exit_status as 'abort'...
#
#
#
# generator repeat ['2939b9e7'] (scan num: 51)
# [E 16:50:03.281 run_engine:1469] Run aborted
#     Traceback (most recent call last):
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py", line 1345, in _run
#         msg = self._plan_stack[-1].send(resp)
#       File "<ipython-input-146-181f55cc9be8>", line 88, in repeat
#         yield from test_aerotech_slipring(cfg)
#       File "<ipython-input-146-181f55cc9be8>", line 84, in test_aerotech_slipring
#         return (yield from scan_closure())
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py", line 1043, in dec_inner
#         return (yield from plan)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 327, in run_wrapper
#         else_plan=close_run)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 563, in contingency_wrapper
#         ret = yield from plan
#       File "<ipython-input-146-181f55cc9be8>", line 82, in scan_closure
#         yield from bps.mv(tomostage.ky, 6.0)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/plan_stubs.py", line 251, in mv
#         yield Msg('wait', None, group=group)
#     bluesky.utils.RequestAbort
# ('f78d918c-60fb-466c-b99e-2e18589b3059',
#  '62a9d0dc-bb95-4031-bc72-df33c7912556',
#  '103c48d6-972e-484c-8908-5a950f5dcecb',
#  '2c9e51fd-f0f8-475f-96ed-a61458e67b07',
#  '3c880df0-486d-41d6-b97e-7de8d657087a',
#  '25c066db-44fd-4531-95e6-ec21087a9222',
#  'c7a9ac32-c2a2-4082-b964-f09c7d179506',
#  '87b1f3ca-5595-46e4-bff0-08def178cb47',
#  '18ab9cce-52f0-46d1-af62-60b6ff3f1971',
#  '1c7e1ebb-bc56-4f36-bce5-5b3dd19f15bf',
#  'ccd16be0-a7eb-4f5b-938b-41fca929d5ac',
#  '24fb69bc-3a3b-41e6-ae6b-8fafaf7046c8',
#  '54c44b5f-56bc-4507-9af3-24adf6b51e9e',
#  '59ddcfc2-d388-481d-b89e-78d022150e1d',
#  'c60175a1-b290-45e1-ba2a-993edea510a5',
#  '6e1d05fc-89d1-4d8b-8f91-23673aca4f34',
#  'ae9043fa-96ff-4791-b28e-442e40eb7e7f',
#  'ac1e9eef-2ea5-4113-8e97-90e19b36a0bf',
#  'f6629f6e-4091-4f59-b9f1-d948d740696e',
#  'c9656304-d84f-4ca0-9518-5509cacab137',
#  'ae78389b-94b5-4182-b73d-593f1dbea692',
#  'eb5d344a-f861-4345-b868-f06c42b77623',
#  '1c48f5d6-57c0-41ee-a770-43a4bc59b7f2',
#  'f9f545b2-2343-4fed-9691-f08cdd58f1af',
#  'e729bf52-2a6b-49e2-8485-c6dc857154e2',
#  'cf1819ac-1cc9-48de-9109-a689dca88e42',
#  'cb11e651-8e38-44af-bc51-1c8d6ad2da13',
#  '9c810ac6-b8a7-4c30-b9d3-8415192bfb67',
#  '1a7406df-c5ea-44b1-8025-0cce4a703835',
#  'ecf23344-1a6c-4f22-8a84-6f8a043bda69',
#  'db9bf4b4-2829-40e4-8c07-eef3682b1ea2',
#  '1721e3ef-955d-48d5-bd7e-ec80d412d617',
#  'fa3eb83d-19cf-4870-b525-74a16bf90529',
#  '6548db9e-33d5-4924-8292-0b934bd0bf0a',
#  '7914598c-e619-4793-84be-515d1a9be39c',
#  '8810f641-5682-471c-a578-8dc71d3b09e7',
#  '4926fd90-7428-4a1d-8883-357ab27c2c7a',
#  '7e9db180-3306-4c8f-bce1-ea8d4ed4f772',
#  'be0ea960-8b14-4366-a9f7-ca47c445a863',
#  '1c4a431b-8e2f-416b-a2b2-e9e576c5dc81',
#  'a3fb2234-ea75-4630-ba1d-71b4d4d80d48',
#  'e91361f0-51f8-4ab5-b53d-1eb8f2892dda',
#  '46696952-0205-4377-8397-0961d4e3736d',
#  '2939b9e7-9c3a-429c-9891-2b78864d2c69')

# %%
tomostage.rot._motor_cal_set.put(1)
tomostage.rot.dial_value.put(tomostage.rot.dial_readback.get()-360)
tomostage.rot._off_value.put(0)
tomostage.rot._motor_cal_set.put(0)

# %%
# -- step scan
def reset():
    yield from bps.mv(tomostage.rot._motor_cal_set, 1)
    yield from bps.mv(tomostage.rot.dial_value,     tomostage.rot.dial_readback.get()-360)
    yield from bps.mv(tomostage.rot._off_value,     0)
    yield from bps.mv(tomostage.rot._motor_cal_set, 0)

    
def step_scan(cfg_tomo):
    """
    Collect projections with step motion
    """

    # TODO:
    # the fields need to be updated for 6-ID-D
    yield from bps.mv(det.hdf1.nd_array_port, 'TRANS1')
    yield from bps.mv(det.tiff1.nd_array_port, 'TRANS1') 
    yield from bps.mv(det.trans1.enable, 1)
    yield from bps.mv(det.trans1.enable_filter, 1)
    yield from bps.mv(det.trans1.reset_filter, 1)
    yield from bps.mv(det.trans1.num_filter, cfg_tomo['n_frames'])
    yield from bps.mv(det.cam1.num_images, cfg_tomo['n_frames'])

    angs = np.arange(
        cfg_tomo['omega_start'], 
        cfg_tomo['omega_end']+cfg_tomo['omega_step']/2,
        cfg_tomo['omega_step'],
    )
    for ang in angs:
        yield from bps.checkpoint()
        if ang<-180 or ang>180:
            yield from reset()
        yield from bps.mv(tomostage.rot, ang)
        yield from bps.mv(fast_shutter, 13)
        yield from bps.trigger_and_read([det])
#         yield from bps.mv(fast_shutter, 14)


# -- white field
def collect_white_field(cfg_tomo, atfront=True):
    """
    Collect white/flat field images by moving the sample out of the FOV
    """  
    # move sample out of the way
    # TODO:
    # the details and fields need to be updated for 6-ID-D
    _x = cfg_tomo['fronte_white_kx'] if atfront else cfg_tomo['back_white_kx']
    _z = cfg_tomo['fronte_white_kz'] if atfront else cfg_tomo['back_white_kz']
    yield from bps.mv(tomostage.kx, _x)  #update with correct motor name
    yield from bps.mv(tomostage.kz, _z)

    # setup detector
    # TODO:
    # actual implementation need to be for 6-ID-D
    yield from bps.mv(det.hdf1.nd_array_port, 'TRANS1')
    yield from bps.mv(det.tiff1.nd_array_port, 'TRANS1') 
    yield from bps.mv(det.trans1.enable, 1)
    yield from bps.mv(det.trans1.enable_filter, 1)
    yield from bps.mv(det.trans1.filter_type, 'Average')
    yield from bps.mv(det.trans1.reset_filter, 1)
    yield from bps.mv(det.trans1.num_filter, cfg_tomo['n_frames'])
    yield from bps.mv(det.cam1.trigger_mode, "Software")
    yield from bps.mv(det.cam1.image_mode, "Multiple")
    yield from bps.mv(det.cam1.num_images, cfg_tomo['n_frames']*cfg_tomo['n_white'])
    yield from bps.mv(fast_shutter, 13)
    yield from bps.trigger_and_read([det])
#     yield from bps.mv(fast_shutter, 14)
    # move sample back to FOV
    # NOTE:
    # not sure is this will work or not...
    # TODO:
    #   need to update all the motor names according to StageAero
    yield from bps.mv(tomostage.kx, cfg_tomo['initial_kx'])
    yield from bps.mv(tomostage.kz, cfg_tomo['initial_kz'])
    

# -- dark field
def collect_dark_field(cfg_tomo):
    """
    Collect dark field images by close the shutter
    """
    # TODO:
    #   Need to toggle Fast shutter

    yield from bps.mv(det.hdf1.nd_array_port, 'TRANS1')
    yield from bps.mv(det.tiff1.nd_array_port, 'TRANS1') 
    yield from bps.mv(det.trans1.enable, 1)
    yield from bps.mv(det.trans1.enable_filter, 1)
    yield from bps.mv(det.trans1.reset_filter, 1)
    yield from bps.mv(det.trans1.num_filter, cfg_tomo['n_frames'])
    yield from bps.mv(det.cam1.trigger_mode, "Software")
    yield from bps.mv(det.cam1.image_mode, "Multiple")
    yield from bps.mv(det.cam1.num_images, cfg_tomo['n_frames']*cfg_tomo['n_dark'])
    yield from bps.mv(fast_shutter, 14)
    yield from bps.trigger_and_read([det])


# -- tomo scan
def tomo_scan(cfg):
    """
    Tomography scan plan based on given configuration
    """
    tomostage.kx.move(-1.460)
    tomostage.kz.move(0.030)
    tomostage.ky.move(16.353)
    
    
    fp = cfg['output']['fp']
    fn = cfg['output']['fn']

    #########################
    ## step 0: preparation ##
    #########################
    acquire_time   = cfg['tomo']['acquire_time']
    acquire_period = cfg['tomo']['acquire_period']
    n_white        = cfg['tomo']['n_white']
    n_dark         = cfg['tomo']['n_dark']
    angs = np.arange(
        cfg['tomo']['omega_start'], 
        cfg['tomo']['omega_end']+cfg['tomo']['omega_step']/2,
        cfg['tomo']['omega_step'],
    )
    n_projections = len(angs)
    cfg['tomo']['n_projections'] = n_projections
    cfg['tomo']['total_images']  = n_white + n_projections + n_white + n_dark


    # calculate slew speed for fly scan
    # https://github.com/decarlof/tomo2bm/blob/master/flir/libs/aps2bm_lib.py
    # TODO: considering blue pixels, use 2BM code as ref

    # need to make sure that the sample out position is the same for both front and back
    x0, z0 = tomostage.kx.position, tomostage.kz.position
    dfx, dfz = cfg['tomo']['sample_out_position']['kx'], cfg['tomo']['sample_out_position']['kz']
    rotang = np.radians(cfg['tomo']['omega_end']-cfg['tomo']['omega_start'])
    rotm = np.array([[ np.cos(rotang), np.sin(rotang)],
                        [-np.sin(rotang), np.cos(rotang)]])
    dbxz = np.dot(rotm, np.array([dfx, dfz]))
    dbx = dbxz[0] if abs(dbxz[0]) > 1e-8 else 0.0
    dbz = dbxz[1] if abs(dbxz[1]) > 1e-8 else 0.0
    # now put the value to dict
    cfg['tomo']['initial_kx']       = x0
    cfg['tomo']['initial_kz']       = z0
    cfg['tomo']['fronte_white_kx']  = x0 + dfx
    cfg['tomo']['fronte_white_kz']  = z0 + dfz
    cfg['tomo']['back_white_kx']    = x0 + dbx
    cfg['tomo']['back_white_kz']    = z0 + dbz

    ###############################################
    ## step 0.9: print out the cfg for user info ##
    ###############################################   
    caput("QIMAGE2:TIFF1:AutoSave", 1)
    @bpp.stage_decorator([det])
    @bpp.run_decorator()
    def scan_closure():
        # TODO:
        #   Somewhere we need to check the light status
        # open shutter for beam

        yield from bps.install_suspender(shutter_suspender)
        # config output
        for me in [det.tiff1, det.hdf1]:
            yield from bps.mv(me.file_path, fp)
            yield from bps.mv(me.file_name, fn)
            yield from bps.mv(me.file_write_mode, 2)
            yield from bps.mv(me.num_capture, cfg['tomo']['total_images'])
            yield from bps.mv(me.file_template, ".".join([r"%s%s_%06d",cfg['output']['type'].lower()]))    

        if cfg['output']['type'] in ['tif', 'tiff']:
            yield from bps.mv(det.tiff1.enable, 1)
            yield from bps.mv(det.tiff1.capture, 1)
            yield from bps.mv(det.hdf1.enable, 0)
        elif cfg['output']['type'] in ['hdf', 'hdf1', 'hdf5']:
            yield from bps.mv(det.tiff1.enable, 0)
            yield from bps.mv(det.hdf1.enable, 1)
            yield from bps.mv(det.hdf1.capture, 1)
        else:
            raise ValueError(f"Unsupported output type {cfg['output']['type']}")
        
#         # open main shutter
#         yield from bps.mv(D_shutter, "open")

        # collect front white field
        yield from bps.mv(det.cam1.frame_type, 0)  # for HDF5 dxchange data structure
        yield from collect_white_field(cfg['tomo'], atfront=True)

        # collect projections
        yield from bps.mv(det.cam1.frame_type, 1)  # for HDF5 dxchange data structure
        if cfg['tomo']['type'].lower() == 'step':
            # setting acquire_time and acquire_period
            yield from bps.mv(det.cam1.acquire_time, acquire_time)
            yield from bps.mv(det.cam1.acquire_period, acquire_period)
            # run step_scan
            yield from step_scan(cfg['tomo'])
        else:
            raise ValueError(f"Unsupported scan type: {cfg['tomo']['type']}")

        # collect back white field
        yield from bps.mv(det.cam1.frame_type, 2)  # for HDF5 dxchange data structure
        yield from collect_white_field(cfg['tomo'], atfront=False)

        # collect back dark field
        yield from bps.mv(det.cam1.frame_type, 3)  # for HDF5 dxchange data structure

#         # TODO: no shutter available for Sim testing
#         yield from bps.remove_suspender(shutter_suspender)
#         yield from bps.mv(D_shutter, "close")
#         yield from bps.mv(fast_shutter, 1)

        yield from collect_dark_field(cfg['tomo'])
        
        yield from bps.mv(det_mtr_x, 50)
        yield from bps.mv(tomostage.ky, 6.0)

    return (yield from scan_closure())

# %%
def repeat(n_turns, cfg):
    for _ in range(n_turns):
        yield from tomo_scan(cfg)
        yield from reset()

# %%
cfg_tomo = {
    'type':    'step',
    'n_white': 5,
    'n_dark':  5,
    'sample_out_position': {
        'kx':  -3,
        'kz':   0,
    },
    'acquire_time':   0.5,
    'acquire_period': 1.0, 
    'omega_step':     10,
    'omega_start':    -180,
    'omega_end':       180,
    'n_frames':       1,   
}

cfg_output = {
    'fn':          'test1',
    'fp':          'Q:\\\\s6idd_dec19\\tomo_HEA1_3\\' ,  # match the ff scan HEA_3
    'type':        'tif',  
}

cfg = {
    'tomo': cfg_tomo,
    'output': cfg_output,
}

# %%
RE(repeat(1, cfg), LiveTable([tomostage.rot]))
# Out:
# Transient Scan ID: 52     Time: 2019-12-13 18:45:28
# Persistent Unique Scan ID: '4dd9f70e-1a57-4b54-9c35-8c84a9c43e77'
#
#
#
# generator repeat ['4dd9f70e'] (scan num: 52)
# [E 18:45:33.420 run_engine:1477] Run aborted
#     Traceback (most recent call last):
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/ophyd/device.py", line 984, in __getattr__
#         cpt = self._sig_attrs[name]
#     KeyError: 'enable_filter'
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py", line 1345, in _run
#         msg = self._plan_stack[-1].send(resp)
#       File "<ipython-input-155-d718638217e7>", line 3, in repeat
#         yield from tomo_scan(cfg)
#       File "<ipython-input-154-cb2a0e923d00>", line 215, in tomo_scan
#         return (yield from scan_closure())
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py", line 1043, in dec_inner
#         return (yield from plan)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 940, in stage_wrapper
#         return (yield from finalize_wrapper(inner(), unstage_devices()))
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 501, in finalize_wrapper
#         ret = yield from plan
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 938, in inner
#         return (yield from plan)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py", line 1043, in dec_inner
#         return (yield from plan)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 327, in run_wrapper
#         else_plan=close_run)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 563, in contingency_wrapper
#         ret = yield from plan
#       File "<ipython-input-154-cb2a0e923d00>", line 185, in scan_closure
#         yield from collect_white_field(cfg['tomo'], atfront=True)
#       File "<ipython-input-154-cb2a0e923d00>", line 58, in collect_white_field
#         yield from bps.mv(det.trans1.enable_filter, 1)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/ophyd/device.py", line 987, in __getattr__
#         raise AttributeError(name)
#     AttributeError: enable_filter
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/ophyd/device.py in __getattr__(self, name)
#     983                 # Initial access of signal
# --> 984                 cpt = self._sig_attrs[name]
#     985                 return cpt.__get__(self, None)
#
# KeyError: 'enable_filter'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-158-ccfcf03e1e7d> in <module>
# ----> 1 RE(repeat(1, cfg), LiveTable([tomostage.rot]))
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in __call__(self, *args, **metadata_kw)
#     791             self._task_fut.add_done_callback(set_blocking_event)
#     792
# --> 793         self._resume_task(init_func=_build_task)
#     794
#     795         if self._interrupted:
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in _resume_task(self, init_func)
#     915                     if (exc is not None
#     916                             and not isinstance(exc, _RunEnginePanic)):
# --> 917                         raise exc
#     918
#     919     def install_suspender(self, suspender):
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in _run(self)
#    1476             exit_reason = str(err)
#    1477             self.log.exception("Run aborted")
# -> 1478             raise err
#    1479         finally:
#    1480             if not exit_reason:
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in _run(self)
#    1343                     else:
#    1344                         try:
# -> 1345                             msg = self._plan_stack[-1].send(resp)
#    1346                         # We have exhausted the top generator
#    1347                         except StopIteration:
#
# <ipython-input-155-d718638217e7> in repeat(n_turns, cfg)
#       1 def repeat(n_turns, cfg):
#       2     for _ in range(n_turns):
# ----> 3         yield from tomo_scan(cfg)
#       4         yield from reset()
#
# <ipython-input-154-cb2a0e923d00> in tomo_scan(cfg)
#     213         yield from bps.mv(tomostage.ky, 6.0)
#     214
# --> 215     return (yield from scan_closure())
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py in dec_inner(*inner_args, **inner_kwargs)
#    1041                 plan = gen_func(*inner_args, **inner_kwargs)
#    1042                 plan = wrapper(plan, *args, **kwargs)
# -> 1043                 return (yield from plan)
#    1044             return dec_inner
#    1045         return dec
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py in stage_wrapper(plan, devices)
#     938         return (yield from plan)
#     939
# --> 940     return (yield from finalize_wrapper(inner(), unstage_devices()))
#     941
#     942
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py in finalize_wrapper(plan, final_plan, pause_for_debug)
#     499     cleanup = True
#     500     try:
# --> 501         ret = yield from plan
#     502     except GeneratorExit:
#     503         cleanup = False
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py in inner()
#     936     def inner():
#     937         yield from stage_devices()
# --> 938         return (yield from plan)
#     939
#     940     return (yield from finalize_wrapper(inner(), unstage_devices()))
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py in dec_inner(*inner_args, **inner_kwargs)
#    1041                 plan = gen_func(*inner_args, **inner_kwargs)
#    1042                 plan = wrapper(plan, *args, **kwargs)
# -> 1043                 return (yield from plan)
#    1044             return dec_inner
#    1045         return dec
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py in run_wrapper(plan, md)
#     325     yield from contingency_wrapper(plan,
#     326                                    except_plan=except_plan,
# --> 327                                    else_plan=close_run)
#     328     return rs_uid
#     329
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py in contingency_wrapper(plan, except_plan, else_plan, final_plan, pause_for_debug)
#     561     cleanup = True
#     562     try:
# --> 563         ret = yield from plan
#     564     except GeneratorExit:
#     565         cleanup = False
#
# <ipython-input-154-cb2a0e923d00> in scan_closure()
#     183         # collect front white field
#     184         yield from bps.mv(det.cam1.frame_type, 0)  # for HDF5 dxchange data structure
# --> 185         yield from collect_white_field(cfg['tomo'], atfront=True)
#     186
#     187         # collect projections
#
# <ipython-input-154-cb2a0e923d00> in collect_white_field(cfg_tomo, atfront)
#      56     yield from bps.mv(det.tiff1.nd_array_port, 'TRANS1')
#      57     yield from bps.mv(det.trans1.enable, 1)
# ---> 58     yield from bps.mv(det.trans1.enable_filter, 1)
#      59     yield from bps.mv(det.trans1.filter_type, 'Average')
#      60     yield from bps.mv(det.trans1.reset_filter, 1)
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/ophyd/device.py in __getattr__(self, name)
#     985                 return cpt.__get__(self, None)
#     986             except KeyError:
# --> 987                 raise AttributeError(name)
#     988
#     989         attr_names = name.split('.')
#
# AttributeError: enable_filter

# %%
# -- step scan
def reset():
    yield from bps.mv(tomostage.rot._motor_cal_set, 1)
    yield from bps.mv(tomostage.rot.dial_value,     tomostage.rot.dial_readback.get()-360)
    yield from bps.mv(tomostage.rot._off_value,     0)
    yield from bps.mv(tomostage.rot._motor_cal_set, 0)

    
def step_scan(cfg_tomo):
    """
    Collect projections with step motion
    """

    # TODO:
    # the fields need to be updated for 6-ID-D
    yield from bps.mv(det.hdf1.nd_array_port, 'TRANS1')
    yield from bps.mv(det.tiff1.nd_array_port, 'TRANS1') 
    yield from bps.mv(det.trans1.enable, 1)
    yield from bps.mv(det.cam1.num_images, cfg_tomo['n_frames'])

    angs = np.arange(
        cfg_tomo['omega_start'], 
        cfg_tomo['omega_end']+cfg_tomo['omega_step']/2,
        cfg_tomo['omega_step'],
    )
    for ang in angs:
        yield from bps.checkpoint()
        if ang<-180 or ang>180:
            yield from reset()
        yield from bps.mv(tomostage.rot, ang)
        yield from bps.mv(fast_shutter, 13)
        yield from bps.trigger_and_read([det])
#         yield from bps.mv(fast_shutter, 14)


# -- white field
def collect_white_field(cfg_tomo, atfront=True):
    """
    Collect white/flat field images by moving the sample out of the FOV
    """  
    # move sample out of the way
    # TODO:
    # the details and fields need to be updated for 6-ID-D
    _x = cfg_tomo['fronte_white_kx'] if atfront else cfg_tomo['back_white_kx']
    _z = cfg_tomo['fronte_white_kz'] if atfront else cfg_tomo['back_white_kz']
    yield from bps.mv(tomostage.kx, _x)  #update with correct motor name
    yield from bps.mv(tomostage.kz, _z)

    # setup detector
    # TODO:
    # actual implementation need to be for 6-ID-D
    yield from bps.mv(det.hdf1.nd_array_port, 'TRANS1')
    yield from bps.mv(det.tiff1.nd_array_port, 'TRANS1') 
    yield from bps.mv(det.trans1.enable, 1)
    yield from bps.mv(det.cam1.trigger_mode, "Software")
    yield from bps.mv(det.cam1.image_mode, "Multiple")
    yield from bps.mv(det.cam1.num_images, cfg_tomo['n_frames']*cfg_tomo['n_white'])
    yield from bps.mv(fast_shutter, 13)
    yield from bps.trigger_and_read([det])
#     yield from bps.mv(fast_shutter, 14)
    # move sample back to FOV
    # NOTE:
    # not sure is this will work or not...
    # TODO:
    #   need to update all the motor names according to StageAero
    yield from bps.mv(tomostage.kx, cfg_tomo['initial_kx'])
    yield from bps.mv(tomostage.kz, cfg_tomo['initial_kz'])
    

# -- dark field
def collect_dark_field(cfg_tomo):
    """
    Collect dark field images by close the shutter
    """
    # TODO:
    #   Need to toggle Fast shutter

    yield from bps.mv(det.hdf1.nd_array_port, 'TRANS1')
    yield from bps.mv(det.tiff1.nd_array_port, 'TRANS1') 
    yield from bps.mv(det.trans1.enable, 1)
    yield from bps.mv(det.cam1.trigger_mode, "Software")
    yield from bps.mv(det.cam1.image_mode, "Multiple")
    yield from bps.mv(det.cam1.num_images, cfg_tomo['n_frames']*cfg_tomo['n_dark'])
    yield from bps.mv(fast_shutter, 14)
    yield from bps.trigger_and_read([det])


# -- tomo scan
def tomo_scan(cfg):
    """
    Tomography scan plan based on given configuration
    """
    tomostage.kx.move(-1.460)
    tomostage.kz.move(0.030)
    tomostage.ky.move(16.353)
    
    
    fp = cfg['output']['fp']
    fn = cfg['output']['fn']

    #########################
    ## step 0: preparation ##
    #########################
    acquire_time   = cfg['tomo']['acquire_time']
    acquire_period = cfg['tomo']['acquire_period']
    n_white        = cfg['tomo']['n_white']
    n_dark         = cfg['tomo']['n_dark']
    angs = np.arange(
        cfg['tomo']['omega_start'], 
        cfg['tomo']['omega_end']+cfg['tomo']['omega_step']/2,
        cfg['tomo']['omega_step'],
    )
    n_projections = len(angs)
    cfg['tomo']['n_projections'] = n_projections
    cfg['tomo']['total_images']  = n_white + n_projections + n_white + n_dark


    # calculate slew speed for fly scan
    # https://github.com/decarlof/tomo2bm/blob/master/flir/libs/aps2bm_lib.py
    # TODO: considering blue pixels, use 2BM code as ref

    # need to make sure that the sample out position is the same for both front and back
    x0, z0 = tomostage.kx.position, tomostage.kz.position
    dfx, dfz = cfg['tomo']['sample_out_position']['kx'], cfg['tomo']['sample_out_position']['kz']
    rotang = np.radians(cfg['tomo']['omega_end']-cfg['tomo']['omega_start'])
    rotm = np.array([[ np.cos(rotang), np.sin(rotang)],
                        [-np.sin(rotang), np.cos(rotang)]])
    dbxz = np.dot(rotm, np.array([dfx, dfz]))
    dbx = dbxz[0] if abs(dbxz[0]) > 1e-8 else 0.0
    dbz = dbxz[1] if abs(dbxz[1]) > 1e-8 else 0.0
    # now put the value to dict
    cfg['tomo']['initial_kx']       = x0
    cfg['tomo']['initial_kz']       = z0
    cfg['tomo']['fronte_white_kx']  = x0 + dfx
    cfg['tomo']['fronte_white_kz']  = z0 + dfz
    cfg['tomo']['back_white_kx']    = x0 + dbx
    cfg['tomo']['back_white_kz']    = z0 + dbz

    ###############################################
    ## step 0.9: print out the cfg for user info ##
    ###############################################   
    caput("QIMAGE2:TIFF1:AutoSave", 1)
    @bpp.stage_decorator([det])
    @bpp.run_decorator()
    def scan_closure():
        # TODO:
        #   Somewhere we need to check the light status
        # open shutter for beam

#         yield from bps.install_suspender(shutter_suspender)
        # config output
        for me in [det.tiff1, det.hdf1]:
            yield from bps.mv(me.file_path, fp)
            yield from bps.mv(me.file_name, fn)
            yield from bps.mv(me.file_write_mode, 2)
            yield from bps.mv(me.num_capture, cfg['tomo']['total_images'])
            yield from bps.mv(me.file_template, ".".join([r"%s%s_%06d",cfg['output']['type'].lower()]))    

        if cfg['output']['type'] in ['tif', 'tiff']:
            yield from bps.mv(det.tiff1.enable, 1)
            yield from bps.mv(det.tiff1.capture, 1)
            yield from bps.mv(det.hdf1.enable, 0)
        elif cfg['output']['type'] in ['hdf', 'hdf1', 'hdf5']:
            yield from bps.mv(det.tiff1.enable, 0)
            yield from bps.mv(det.hdf1.enable, 1)
            yield from bps.mv(det.hdf1.capture, 1)
        else:
            raise ValueError(f"Unsupported output type {cfg['output']['type']}")
        
#         # open main shutter
#         yield from bps.mv(D_shutter, "open")

        # collect front white field
        yield from bps.mv(det.cam1.frame_type, 0)  # for HDF5 dxchange data structure
        yield from collect_white_field(cfg['tomo'], atfront=True)

        # collect projections
        yield from bps.mv(det.cam1.frame_type, 1)  # for HDF5 dxchange data structure
        if cfg['tomo']['type'].lower() == 'step':
            # setting acquire_time and acquire_period
            yield from bps.mv(det.cam1.acquire_time, acquire_time)
            yield from bps.mv(det.cam1.acquire_period, acquire_period)
            # run step_scan
            yield from step_scan(cfg['tomo'])
        else:
            raise ValueError(f"Unsupported scan type: {cfg['tomo']['type']}")

        # collect back white field
        yield from bps.mv(det.cam1.frame_type, 2)  # for HDF5 dxchange data structure
        yield from collect_white_field(cfg['tomo'], atfront=False)

        # collect back dark field
        yield from bps.mv(det.cam1.frame_type, 3)  # for HDF5 dxchange data structure

#         # TODO: no shutter available for Sim testing
#         yield from bps.remove_suspender(shutter_suspender)
#         yield from bps.mv(D_shutter, "close")
#         yield from bps.mv(fast_shutter, 1)

        yield from collect_dark_field(cfg['tomo'])
        
        yield from bps.mv(det_mtr_x, 50)
        yield from bps.mv(tomostage.ky, 6.0)

    return (yield from scan_closure())
# Out:
# Suspender SuspendFloor(EpicsSignalRO(read_pv='PA:06ID:STA_D_SDS_OPEN_PL', name='D_shutter_pss_state', parent='D_shutter', value=1, timestamp=1576284484.167936, pv_kw={}, auto_monitor=False, string=False), sleep=0, pre_plan=None, post_plan=None,tripped_message=) reports a return to nominal conditions. Will sleep for 0 seconds and then release suspension at 2019-12-13 18:48:04.

# %%
RE.remove_suspender(shutter_suspender)

# %%
RE(repeat(1, cfg), LiveTable([tomostage.rot]))
# Out:
# Transient Scan ID: 53     Time: 2019-12-13 18:49:20
# Persistent Unique Scan ID: '8d3254dc-52a5-465e-86a8-adea96a612c6'
# New stream: 'primary'
# +-----------+------------+
# |   seq_num |       time |
# +-----------+------------+
# +-----------+------------+
# |   seq_num |       time |
# +-----------+------------+
# |         1 | 18:49:30.8 |
# |         1 | 18:49:30.8 |
# |         2 | 18:49:36.6 |
# |         2 | 18:49:36.6 |
# |         3 | 18:49:40.1 |
# |         3 | 18:49:40.1 |
# |         4 | 18:49:43.6 |
# |         4 | 18:49:43.6 |
# |         5 | 18:49:47.1 |
# |         5 | 18:49:47.1 |
# |         6 | 18:49:50.6 |
# |         6 | 18:49:50.6 |
# |         7 | 18:49:54.1 |
# |         7 | 18:49:54.1 |
# |         8 | 18:49:57.6 |
# |         8 | 18:49:57.6 |
# |         9 | 18:50:01.1 |
# |         9 | 18:50:01.1 |
# |        10 | 18:50:04.6 |
# |        10 | 18:50:04.6 |
# |        11 | 18:50:08.1 |
# |        11 | 18:50:08.1 |
# |        12 | 18:50:11.6 |
# |        12 | 18:50:11.6 |
# |        13 | 18:50:15.1 |
# |        13 | 18:50:15.1 |
# |        14 | 18:50:18.6 |
# |        14 | 18:50:18.6 |
# |        15 | 18:50:22.1 |
# |        15 | 18:50:22.1 |
# |        16 | 18:50:25.6 |
# |        16 | 18:50:25.6 |
# |        17 | 18:50:29.1 |
# |        17 | 18:50:29.1 |
# |        18 | 18:50:32.6 |
# |        18 | 18:50:32.6 |
# |        19 | 18:50:36.2 |
# |        19 | 18:50:36.2 |
# |        20 | 18:50:39.7 |
# |        20 | 18:50:39.7 |
# |        21 | 18:50:43.2 |
# |        21 | 18:50:43.2 |
# |        22 | 18:50:46.7 |
# |        22 | 18:50:46.7 |
# |        23 | 18:50:50.2 |
# |        23 | 18:50:50.2 |
# |        24 | 18:50:53.7 |
# |        24 | 18:50:53.7 |
# |        25 | 18:50:57.2 |
# |        25 | 18:50:57.2 |
# |        26 | 18:51:00.7 |
# |        26 | 18:51:00.7 |
# |        27 | 18:51:04.2 |
# |        27 | 18:51:04.2 |
# |        28 | 18:51:07.7 |
# |        28 | 18:51:07.7 |
# |        29 | 18:51:11.2 |
# |        29 | 18:51:11.2 |
# |        30 | 18:51:14.7 |
# |        30 | 18:51:14.7 |
# |        31 | 18:51:18.2 |
# |        31 | 18:51:18.2 |
# |        32 | 18:51:21.7 |
# |        32 | 18:51:21.7 |
# |        33 | 18:51:25.2 |
# |        33 | 18:51:25.2 |
# |        34 | 18:51:28.7 |
# |        34 | 18:51:28.7 |
# |        35 | 18:51:32.2 |
# |        35 | 18:51:32.2 |
# |        36 | 18:51:35.7 |
# |        36 | 18:51:35.7 |
# |        37 | 18:51:39.2 |
# |        37 | 18:51:39.2 |
# |        38 | 18:51:42.7 |
# |        38 | 18:51:42.7 |
# |        39 | 18:51:52.6 |
# |        39 | 18:51:52.6 |
# |        40 | 18:52:02.8 |
# |        40 | 18:52:02.8 |
# +-----------+------------+
# generator repeat ['8d3254dc'] (scan num: 53)
#
#
#
# +-----------+------------+
# generator repeat ['8d3254dc'] (scan num: 53)
# [E 18:52:03.172 run_engine:1477] Run aborted
#     Traceback (most recent call last):
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py", line 1345, in _run
#         msg = self._plan_stack[-1].send(resp)
#       File "<ipython-input-155-d718638217e7>", line 3, in repeat
#         yield from tomo_scan(cfg)
#       File "<ipython-input-159-7bd0cc6fa56a>", line 205, in tomo_scan
#         return (yield from scan_closure())
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py", line 1043, in dec_inner
#         return (yield from plan)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 940, in stage_wrapper
#         return (yield from finalize_wrapper(inner(), unstage_devices()))
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 501, in finalize_wrapper
#         ret = yield from plan
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 938, in inner
#         return (yield from plan)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py", line 1043, in dec_inner
#         return (yield from plan)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 327, in run_wrapper
#         else_plan=close_run)
#       File "/home/beams/S6HEDM/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py", line 563, in contingency_wrapper
#         ret = yield from plan
#       File "<ipython-input-159-7bd0cc6fa56a>", line 202, in scan_closure
#         yield from bps.mv(det_mtr_x, 50)
#     NameError: name 'det_mtr_x' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-161-ccfcf03e1e7d> in <module>
# ----> 1 RE(repeat(1, cfg), LiveTable([tomostage.rot]))
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in __call__(self, *args, **metadata_kw)
#     791             self._task_fut.add_done_callback(set_blocking_event)
#     792
# --> 793         self._resume_task(init_func=_build_task)
#     794
#     795         if self._interrupted:
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in _resume_task(self, init_func)
#     915                     if (exc is not None
#     916                             and not isinstance(exc, _RunEnginePanic)):
# --> 917                         raise exc
#     918
#     919     def install_suspender(self, suspender):
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in _run(self)
#    1476             exit_reason = str(err)
#    1477             self.log.exception("Run aborted")
# -> 1478             raise err
#    1479         finally:
#    1480             if not exit_reason:
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/run_engine.py in _run(self)
#    1343                     else:
#    1344                         try:
# -> 1345                             msg = self._plan_stack[-1].send(resp)
#    1346                         # We have exhausted the top generator
#    1347                         except StopIteration:
#
# <ipython-input-155-d718638217e7> in repeat(n_turns, cfg)
#       1 def repeat(n_turns, cfg):
#       2     for _ in range(n_turns):
# ----> 3         yield from tomo_scan(cfg)
#       4         yield from reset()
#
# <ipython-input-159-7bd0cc6fa56a> in tomo_scan(cfg)
#     203         yield from bps.mv(tomostage.ky, 6.0)
#     204
# --> 205     return (yield from scan_closure())
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py in dec_inner(*inner_args, **inner_kwargs)
#    1041                 plan = gen_func(*inner_args, **inner_kwargs)
#    1042                 plan = wrapper(plan, *args, **kwargs)
# -> 1043                 return (yield from plan)
#    1044             return dec_inner
#    1045         return dec
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py in stage_wrapper(plan, devices)
#     938         return (yield from plan)
#     939
# --> 940     return (yield from finalize_wrapper(inner(), unstage_devices()))
#     941
#     942
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py in finalize_wrapper(plan, final_plan, pause_for_debug)
#     499     cleanup = True
#     500     try:
# --> 501         ret = yield from plan
#     502     except GeneratorExit:
#     503         cleanup = False
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py in inner()
#     936     def inner():
#     937         yield from stage_devices()
# --> 938         return (yield from plan)
#     939
#     940     return (yield from finalize_wrapper(inner(), unstage_devices()))
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/utils.py in dec_inner(*inner_args, **inner_kwargs)
#    1041                 plan = gen_func(*inner_args, **inner_kwargs)
#    1042                 plan = wrapper(plan, *args, **kwargs)
# -> 1043                 return (yield from plan)
#    1044             return dec_inner
#    1045         return dec
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py in run_wrapper(plan, md)
#     325     yield from contingency_wrapper(plan,
#     326                                    except_plan=except_plan,
# --> 327                                    else_plan=close_run)
#     328     return rs_uid
#     329
#
# ~/opt/anaconda3/envs/beamline/lib/python3.7/site-packages/bluesky/preprocessors.py in contingency_wrapper(plan, except_plan, else_plan, final_plan, pause_for_debug)
#     561     cleanup = True
#     562     try:
# --> 563         ret = yield from plan
#     564     except GeneratorExit:
#     565         cleanup = False
#
# <ipython-input-159-7bd0cc6fa56a> in scan_closure()
#     200         yield from collect_dark_field(cfg['tomo'])
#     201
# --> 202         yield from bps.mv(det_mtr_x, 50)
#     203         yield from bps.mv(tomostage.ky, 6.0)
#     204
#
# NameError: name 'det_mtr_x' is not defined

# %%
# -- step scan
def reset():
    yield from bps.mv(tomostage.rot._motor_cal_set, 1)
    yield from bps.mv(tomostage.rot.dial_value,     tomostage.rot.dial_readback.get()-360)
    yield from bps.mv(tomostage.rot._off_value,     0)
    yield from bps.mv(tomostage.rot._motor_cal_set, 0)

    
def step_scan(cfg_tomo):
    """
    Collect projections with step motion
    """

    # TODO:
    # the fields need to be updated for 6-ID-D
    yield from bps.mv(det.hdf1.nd_array_port, 'TRANS1')
    yield from bps.mv(det.tiff1.nd_array_port, 'TRANS1') 
    yield from bps.mv(det.trans1.enable, 1)
    yield from bps.mv(det.cam1.num_images, cfg_tomo['n_frames'])

    angs = np.arange(
        cfg_tomo['omega_start'], 
        cfg_tomo['omega_end']+cfg_tomo['omega_step']/2,
        cfg_tomo['omega_step'],
    )
    for ang in angs:
        yield from bps.checkpoint()
        if ang<-180 or ang>180:
            yield from reset()
        yield from bps.mv(tomostage.rot, ang)
        yield from bps.mv(fast_shutter, 13)
        yield from bps.trigger_and_read([det])
#         yield from bps.mv(fast_shutter, 14)


# -- white field
def collect_white_field(cfg_tomo, atfront=True):
    """
    Collect white/flat field images by moving the sample out of the FOV
    """  
    # move sample out of the way
    # TODO:
    # the details and fields need to be updated for 6-ID-D
    _x = cfg_tomo['fronte_white_kx'] if atfront else cfg_tomo['back_white_kx']
    _z = cfg_tomo['fronte_white_kz'] if atfront else cfg_tomo['back_white_kz']
    yield from bps.mv(tomostage.kx, _x)  #update with correct motor name
    yield from bps.mv(tomostage.kz, _z)

    # setup detector
    # TODO:
    # actual implementation need to be for 6-ID-D
    yield from bps.mv(det.hdf1.nd_array_port, 'TRANS1')
    yield from bps.mv(det.tiff1.nd_array_port, 'TRANS1') 
    yield from bps.mv(det.trans1.enable, 1)
    yield from bps.mv(det.cam1.trigger_mode, "Software")
    yield from bps.mv(det.cam1.image_mode, "Multiple")
    yield from bps.mv(det.cam1.num_images, cfg_tomo['n_frames']*cfg_tomo['n_white'])
    yield from bps.mv(fast_shutter, 13)
    yield from bps.trigger_and_read([det])
#     yield from bps.mv(fast_shutter, 14)
    # move sample back to FOV
    # NOTE:
    # not sure is this will work or not...
    # TODO:
    #   need to update all the motor names according to StageAero
    yield from bps.mv(tomostage.kx, cfg_tomo['initial_kx'])
    yield from bps.mv(tomostage.kz, cfg_tomo['initial_kz'])
    

# -- dark field
def collect_dark_field(cfg_tomo):
    """
    Collect dark field images by close the shutter
    """
    # TODO:
    #   Need to toggle Fast shutter

    yield from bps.mv(det.hdf1.nd_array_port, 'TRANS1')
    yield from bps.mv(det.tiff1.nd_array_port, 'TRANS1') 
    yield from bps.mv(det.trans1.enable, 1)
    yield from bps.mv(det.cam1.trigger_mode, "Software")
    yield from bps.mv(det.cam1.image_mode, "Multiple")
    yield from bps.mv(det.cam1.num_images, cfg_tomo['n_frames']*cfg_tomo['n_dark'])
    yield from bps.mv(fast_shutter, 14)
    yield from bps.trigger_and_read([det])


# -- tomo scan
def tomo_scan(cfg):
    """
    Tomography scan plan based on given configuration
    """
    tomostage.kx.move(-1.460)
    tomostage.kz.move(0.030)
    tomostage.ky.move(16.353)
    
    
    fp = cfg['output']['fp']
    fn = cfg['output']['fn']

    #########################
    ## step 0: preparation ##
    #########################
    acquire_time   = cfg['tomo']['acquire_time']
    acquire_period = cfg['tomo']['acquire_period']
    n_white        = cfg['tomo']['n_white']
    n_dark         = cfg['tomo']['n_dark']
    angs = np.arange(
        cfg['tomo']['omega_start'], 
        cfg['tomo']['omega_end']+cfg['tomo']['omega_step']/2,
        cfg['tomo']['omega_step'],
    )
    n_projections = len(angs)
    cfg['tomo']['n_projections'] = n_projections
    cfg['tomo']['total_images']  = n_white + n_projections + n_white + n_dark


    # calculate slew speed for fly scan
    # https://github.com/decarlof/tomo2bm/blob/master/flir/libs/aps2bm_lib.py
    # TODO: considering blue pixels, use 2BM code as ref

    # need to make sure that the sample out position is the same for both front and back
    x0, z0 = tomostage.kx.position, tomostage.kz.position
    dfx, dfz = cfg['tomo']['sample_out_position']['kx'], cfg['tomo']['sample_out_position']['kz']
    rotang = np.radians(cfg['tomo']['omega_end']-cfg['tomo']['omega_start'])
    rotm = np.array([[ np.cos(rotang), np.sin(rotang)],
                        [-np.sin(rotang), np.cos(rotang)]])
    dbxz = np.dot(rotm, np.array([dfx, dfz]))
    dbx = dbxz[0] if abs(dbxz[0]) > 1e-8 else 0.0
    dbz = dbxz[1] if abs(dbxz[1]) > 1e-8 else 0.0
    # now put the value to dict
    cfg['tomo']['initial_kx']       = x0
    cfg['tomo']['initial_kz']       = z0
    cfg['tomo']['fronte_white_kx']  = x0 + dfx
    cfg['tomo']['fronte_white_kz']  = z0 + dfz
    cfg['tomo']['back_white_kx']    = x0 + dbx
    cfg['tomo']['back_white_kz']    = z0 + dbz

    ###############################################
    ## step 0.9: print out the cfg for user info ##
    ###############################################   
    caput("QIMAGE2:TIFF1:AutoSave", 1)
    @bpp.stage_decorator([det])
    @bpp.run_decorator()
    def scan_closure():
        # TODO:
        #   Somewhere we need to check the light status
        # open shutter for beam

#         yield from bps.install_suspender(shutter_suspender)
        # config output
        for me in [det.tiff1, det.hdf1]:
            yield from bps.mv(me.file_path, fp)
            yield from bps.mv(me.file_name, fn)
            yield from bps.mv(me.file_write_mode, 2)
            yield from bps.mv(me.num_capture, cfg['tomo']['total_images'])
            yield from bps.mv(me.file_template, ".".join([r"%s%s_%06d",cfg['output']['type'].lower()]))    

        if cfg['output']['type'] in ['tif', 'tiff']:
            yield from bps.mv(det.tiff1.enable, 1)
            yield from bps.mv(det.tiff1.capture, 1)
            yield from bps.mv(det.hdf1.enable, 0)
        elif cfg['output']['type'] in ['hdf', 'hdf1', 'hdf5']:
            yield from bps.mv(det.tiff1.enable, 0)
            yield from bps.mv(det.hdf1.enable, 1)
            yield from bps.mv(det.hdf1.capture, 1)
        else:
            raise ValueError(f"Unsupported output type {cfg['output']['type']}")
        
#         # open main shutter
#         yield from bps.mv(D_shutter, "open")

        # collect front white field
        yield from bps.mv(det.cam1.frame_type, 0)  # for HDF5 dxchange data structure
        yield from collect_white_field(cfg['tomo'], atfront=True)

        # collect projections
        yield from bps.mv(det.cam1.frame_type, 1)  # for HDF5 dxchange data structure
        if cfg['tomo']['type'].lower() == 'step':
            # setting acquire_time and acquire_period
            yield from bps.mv(det.cam1.acquire_time, acquire_time)
            yield from bps.mv(det.cam1.acquire_period, acquire_period)
            # run step_scan
            yield from step_scan(cfg['tomo'])
        else:
            raise ValueError(f"Unsupported scan type: {cfg['tomo']['type']}")

        # collect back white field
        yield from bps.mv(det.cam1.frame_type, 2)  # for HDF5 dxchange data structure
        yield from collect_white_field(cfg['tomo'], atfront=False)

        # collect back dark field
        yield from bps.mv(det.cam1.frame_type, 3)  # for HDF5 dxchange data structure

#         # TODO: no shutter available for Sim testing
#         yield from bps.remove_suspender(shutter_suspender)
#         yield from bps.mv(D_shutter, "close")
#         yield from bps.mv(fast_shutter, 1)

        yield from collect_dark_field(cfg['tomo'])
        
#         yield from bps.mv(det_mtr_x, 50)
#         yield from bps.mv(tomostage.ky, 6.0)

    return (yield from scan_closure())

# %%
def force_reset():
    tomostage.rot._motor_cal_set.put(1)
    #_current_rot_pos = tomostage.rot._dialreadback.get()
    tomostage.rot.dial_value.put(tomostage.rot.dial_readback.get()-360)
    tomostage.rot._off_value.put(0)
    tomostage.rot._motor_cal_set.put(0)

# %%
force_reset()

# %%
RE(repeat(1, cfg), LiveTable([tomostage.rot]))
# Out:
# Transient Scan ID: 54     Time: 2019-12-13 18:55:49
# Persistent Unique Scan ID: '439f4f05-bc92-4f7e-9e9b-878e80425f9e'
# New stream: 'primary'
# +-----------+------------+
# |   seq_num |       time |
# +-----------+------------+
# +-----------+------------+
# |   seq_num |       time |
# +-----------+------------+
# |         1 | 18:56:00.0 |
# |         1 | 18:56:00.0 |
# |         2 | 18:56:05.8 |
# |         2 | 18:56:05.8 |
# |         3 | 18:56:09.3 |
# |         3 | 18:56:09.3 |
# |         4 | 18:56:12.8 |
# |         4 | 18:56:12.8 |
# |         5 | 18:56:16.3 |
# |         5 | 18:56:16.3 |
# |         6 | 18:56:19.8 |
# |         6 | 18:56:19.8 |
# |         7 | 18:56:23.3 |
# |         7 | 18:56:23.3 |
# |         8 | 18:56:26.8 |
# |         8 | 18:56:26.8 |
# |         9 | 18:56:30.3 |
# |         9 | 18:56:30.3 |
# |        10 | 18:56:33.8 |
# |        10 | 18:56:33.8 |
# |        11 | 18:56:37.3 |
# |        11 | 18:56:37.3 |
# |        12 | 18:56:40.8 |
# |        12 | 18:56:40.8 |
# |        13 | 18:56:44.4 |
# |        13 | 18:56:44.4 |
# |        14 | 18:56:47.9 |
# |        14 | 18:56:47.9 |
# |        15 | 18:56:51.4 |
# |        15 | 18:56:51.4 |
# |        16 | 18:56:54.9 |
# |        16 | 18:56:54.9 |
# |        17 | 18:56:58.4 |
# |        17 | 18:56:58.4 |
# |        18 | 18:57:01.9 |
# |        18 | 18:57:01.9 |
# |        19 | 18:57:05.4 |
# |        19 | 18:57:05.4 |
# |        20 | 18:57:08.9 |
# |        20 | 18:57:08.9 |
# |        21 | 18:57:12.4 |
# |        21 | 18:57:12.4 |
# |        22 | 18:57:15.9 |
# |        22 | 18:57:15.9 |
# |        23 | 18:57:19.4 |
# |        23 | 18:57:19.4 |
# |        24 | 18:57:22.9 |
# |        24 | 18:57:22.9 |
# |        25 | 18:57:26.4 |
# |        25 | 18:57:26.4 |
# |        26 | 18:57:29.9 |
# |        26 | 18:57:29.9 |
# |        27 | 18:57:33.4 |
# |        27 | 18:57:33.4 |
# |        28 | 18:57:36.9 |
# |        28 | 18:57:36.9 |
# |        29 | 18:57:40.5 |
# |        29 | 18:57:40.5 |
# |        30 | 18:57:44.0 |
# |        30 | 18:57:44.0 |
# |        31 | 18:57:47.5 |
# |        31 | 18:57:47.5 |
# |        32 | 18:57:50.9 |
# |        32 | 18:57:50.9 |
# |        33 | 18:57:54.5 |
# |        33 | 18:57:54.5 |
# |        34 | 18:57:58.0 |
# |        34 | 18:57:58.0 |
# |        35 | 18:58:01.5 |
# |        35 | 18:58:01.5 |
# |        36 | 18:58:05.0 |
# |        36 | 18:58:05.0 |
# |        37 | 18:58:08.5 |
# |        37 | 18:58:08.5 |
# |        38 | 18:58:12.1 |
# |        38 | 18:58:12.1 |
# |        39 | 18:58:22.1 |
# |        39 | 18:58:22.1 |
# |        40 | 18:58:32.2 |
# |        40 | 18:58:32.2 |
# +-----------+------------+
# generator repeat ['439f4f05'] (scan num: 54)
#
#
#
# +-----------+------------+
# generator repeat ['439f4f05'] (scan num: 54)
# ('439f4f05-bc92-4f7e-9e9b-878e80425f9e',)

# %% [markdown]
# CeO2

# %%
det.cam1.acquire.put(1)
